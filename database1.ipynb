# %%
import os
import pandas as pd
from sqlalchemy import create_engine, Column, Integer, String, Float, inspect, Table
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker

# Remote database connection URL
REMOTE_DATABASE_URL = "postgresql://udvgghkgvhno05:pdb4ac0e3d9341327385cc1514256906b3ea3cee34a8bfca9f9878e3ecb829408@c6i386kdr73gcp.cluster-czz5s0kz4scl.eu-west-1.rds.amazonaws.com:5432/d3p1stj7ab710b"

# Directory containing the CSV files
csv_directory = "data/SC/census2022-uv205"

# Create a connection to the remote database
engine = create_engine(REMOTE_DATABASE_URL)
Base = declarative_base()

# Create a session
Session = sessionmaker(bind=engine)
session = Session()

# Function to create a table class dynamically based on the CSV file
def create_table_class(table_name, columns):
    class_name = f"Table_{table_name}"
    table_attributes = {"__tablename__": table_name, "id": Column(Integer, primary_key=True), "__table_args__": {"extend_existing": True}}

    for column_name, column_type in columns.items():
        if column_type == "int":
            table_attributes[column_name] = Column(Integer)
        elif column_type == "float":
            table_attributes[column_name] = Column(Float)
        else:
            table_attributes[column_name] = Column(String)

    return type(class_name, (Base,), table_attributes)

# Iterate over the CSV files in the directory
for filename in os.listdir(csv_directory):
    if filename.endswith(".csv"):
        file_path = os.path.join(csv_directory, filename)
        table_name = os.path.splitext(filename)[0]

        # Check if the table already exists in the database
        inspector = inspect(engine)
        if table_name in inspector.get_table_names():
            # Check if the table is empty
            table = Table(table_name, Base.metadata, autoload_with=engine)
            table_empty = session.query(table).count() == 0

            if not table_empty:
                print(f"Table {table_name} already exists and is not empty. Skipping insertion.")
                continue

        # Read the CSV file into a pandas DataFrame
        df = pd.read_csv(file_path)

        # Replace "-" values with "0"
        df = df.replace("-", "0")

        # Determine the column types based on the DataFrame
        column_types = {}
        for column_name, column_data in df.items():
            if column_data.dtype == "int64":
                column_types[column_name] = "int"
            elif column_data.dtype == "float64":
                column_types[column_name] = "float"
            else:
                column_types[column_name] = "str"

        # Create the table class dynamically
        TableClass = create_table_class(table_name, column_types)

        # Create the table in the database (if it doesn't exist)
        Base.metadata.create_all(engine)

        # Clear the existing data from the table (if any)
        session.query(TableClass).delete()
        session.commit()

        # Insert the data from the DataFrame into the table
        for _, row in df.iterrows():
            table_instance = TableClass(**row.to_dict())
            session.add(table_instance)

        session.commit()
        print(f"Inserted data from {filename} into table {table_name}")

session.close()
# Out:
# /var/folders/9d/jc2663851_lgqff4sx4jlfz40000gn/T/ipykernel_77656/2220086727.py:15: MovedIn20Warning: The ``declarative_base()`` function is now available as sqlalchemy.orm.declarative_base(). (deprecated since: 2.0) (Background on SQLAlchemy 2.0 at: https://sqlalche.me/e/b8d9)
#   Base = declarative_base()
# Table census2022-uv205-ctry already exists and is not empty. Skipping insertion.
# Table census2022-uv205-ca already exists and is not empty. Skipping insertion.
# Inserted data from census2022-uv205-oa.csv into table census2022-uv205-oa

# %%
import psycopg2
from psycopg2 import sql
import bcrypt

# Database connection parameters
DATABASE_URL = "postgres://ewhpdfzafeyjhb:4a16e046ac86cb07d825eb32b4223a542c872f8df232e1dad0656916c426c2fc@ec2-52-31-2-97.eu-west-1.compute.amazonaws.com:5432/d35kfnbqn0jb3t"

# Connect to the database
conn = psycopg2.connect(DATABASE_URL, sslmode='require')
cur = conn.cursor()

# Create the 'users' table with a larger password column
create_table_query = """
CREATE TABLE IF NOT EXISTS users (
    username VARCHAR(50) PRIMARY KEY,
    password VARCHAR(60) NOT NULL
);
"""
cur.execute(create_table_query)
conn.commit()

# Hash the password
password = 'password'
hashed_password = bcrypt.hashpw(password.encode('utf-8'), bcrypt.gensalt())

# Insert entries into the 'users' table
insert_query = """
INSERT INTO users (username, password) VALUES (%s, %s)
ON CONFLICT (username) DO NOTHING;
"""
cur.execute(insert_query, ('admin', hashed_password.decode('utf-8')))
conn.commit()

# Verify the insertion
cur.execute("SELECT * FROM users;")
rows = cur.fetchall()
for row in rows:
    print(row)

# Close the cursor and connection
cur.close()
conn.close()
# Out:
# ('admin', '$2b$12$DZY95gDJ.4VYwer9diKnfumGfksDDEKJlUn8YBtoVXg4NUYeevyei')

# %%
import os
import psycopg2
from psycopg2 import sql
from dotenv import load_dotenv
import io

# Load environment variables from .env file
load_dotenv()

# Local database connection parameters
LOCAL_DB_HOST = 'localhost'
LOCAL_DB_PORT = '5432'
LOCAL_DB_USER = 'cardigan'
LOCAL_DB_NAME = 'asylum-seekers'

# Remote database connection URL
REMOTE_DATABASE_URL = "postgres://udvgghkgvhno05:pdb4ac0e3d9341327385cc1514256906b3ea3cee34a8bfca9f9878e3ecb829408@c6i386kdr73gcp.cluster-czz5s0kz4scl.eu-west-1.rds.amazonaws.com:5432/d3p1stj7ab710b"

# Connect to the local database
local_conn = psycopg2.connect(
    host=LOCAL_DB_HOST,
    port=LOCAL_DB_PORT,
    user=LOCAL_DB_USER,
    dbname=LOCAL_DB_NAME
)
local_cur = local_conn.cursor()

# Connect to the remote database
remote_conn = psycopg2.connect(REMOTE_DATABASE_URL, sslmode='require')
remote_cur = remote_conn.cursor()

def table_exists(table_name):
    remote_cur.execute("""
    SELECT EXISTS (
        SELECT FROM information_schema.tables 
        WHERE table_name = %s
    );
    """, (table_name,))
    return remote_cur.fetchone()[0]

def get_row_count(conn, table_name):
    cur = conn.cursor()
    cur.execute(sql.SQL("SELECT COUNT(*) FROM {}").format(sql.Identifier(table_name)))
    row_count = cur.fetchone()[0]
    cur.close()
    return row_count

def copy_table(table_name, columns_to_copy, batch_size=5000):
    # Check if the table already exists in the remote database
    if table_exists(table_name):
        print(f"Table {table_name} already exists in the remote database. Checking row counts...")

        # Get row counts for local and remote tables
        local_row_count = get_row_count(local_conn, table_name)
        remote_row_count = get_row_count(remote_conn, table_name)

        if remote_row_count >= local_row_count:
            print(f"Table {table_name} in the remote database is up-to-date. Skipping...")
            return
        else:
            print(f"Table {table_name} in the remote database is shorter. Continuing from row {remote_row_count}...")

    # Fetch data from the local table in batches
    offset = remote_row_count if table_exists(table_name) else 0
    while True:
        select_columns = [sql.Identifier(col) for col in columns_to_copy]
        local_cur.execute(sql.SQL("SELECT {} FROM {} OFFSET %s LIMIT %s").format(
            sql.SQL(', ').join(select_columns),
            sql.Identifier(table_name)
        ), [offset, batch_size])
        rows = local_cur.fetchall()
        if not rows:
            break

        # Filter and format rows
        filtered_rows = []
        for row in rows:
            formatted_row = []
            for i in range(len(columns_to_copy)):
                value = str(row[i]) if i < len(row) else ''
                # Escape double quotes within the value and enclose the value in double quotes
                formatted_value = f'"{value.replace('"', '""')}"'
                formatted_row.append(formatted_value)
            filtered_rows.append(formatted_row)

        # Use COPY command to insert data into the remote table
        copy_query = sql.SQL("COPY {} ({}) FROM STDIN WITH (FORMAT CSV)").format(
            sql.Identifier(table_name),
            sql.SQL(', ').join(map(sql.Identifier, columns_to_copy))
        )
        remote_cur.copy_expert(copy_query, io.StringIO('\n'.join(','.join(row) for row in filtered_rows)))
        remote_conn.commit()
        offset += len(rows)
        print(f"Copied {offset} rows to {table_name}")

# Specify the columns to copy from the local 'geography_mappings' table
columns_to_copy = ['ltla', 'msoa', 'lsoa', 'oa', 'pcd']

# Copy the specified columns to the 'geography_mappings' table in the remote database
copy_table('geography_mappings', columns_to_copy)

# Close the cursors and connections
local_cur.close()
local_conn.close()
remote_cur.close()
remote_conn.close()

print("Columns copied successfully from local to remote 'geography_mappings' table.")
# Out:
# Table geography_mappings already exists in the remote database. Checking row counts...
# Table geography_mappings in the remote database is shorter. Continuing from row 15000...
# Copied 20000 rows to geography_mappings
# Copied 25000 rows to geography_mappings
# Copied 30000 rows to geography_mappings
# Copied 35000 rows to geography_mappings
# Copied 40000 rows to geography_mappings
# Copied 45000 rows to geography_mappings
# Copied 50000 rows to geography_mappings
# Copied 55000 rows to geography_mappings
# Copied 60000 rows to geography_mappings
# Copied 65000 rows to geography_mappings
# Copied 70000 rows to geography_mappings
# Copied 75000 rows to geography_mappings
# Copied 80000 rows to geography_mappings
# Copied 85000 rows to geography_mappings
# Copied 90000 rows to geography_mappings
# Copied 95000 rows to geography_mappings
# Copied 100000 rows to geography_mappings
# Copied 105000 rows to geography_mappings
# Copied 110000 rows to geography_mappings
# Copied 115000 rows to geography_mappings
# Copied 120000 rows to geography_mappings
# Copied 125000 rows to geography_mappings
# Copied 130000 rows to geography_mappings
# Copied 135000 rows to geography_mappings
# Copied 140000 rows to geography_mappings
# Copied 145000 rows to geography_mappings
# Copied 150000 rows to geography_mappings
# Copied 155000 rows to geography_mappings
# Copied 160000 rows to geography_mappings
# Copied 165000 rows to geography_mappings
# Copied 170000 rows to geography_mappings
# Copied 175000 rows to geography_mappings
# Copied 180000 rows to geography_mappings
# Copied 185000 rows to geography_mappings
# Copied 190000 rows to geography_mappings
# Copied 195000 rows to geography_mappings
# Copied 200000 rows to geography_mappings
# Copied 205000 rows to geography_mappings
# Copied 210000 rows to geography_mappings
# Copied 215000 rows to geography_mappings
# Copied 220000 rows to geography_mappings
# Copied 225000 rows to geography_mappings
# Copied 230000 rows to geography_mappings
# Copied 235000 rows to geography_mappings
# Copied 240000 rows to geography_mappings
# Copied 245000 rows to geography_mappings
# Copied 250000 rows to geography_mappings
# Copied 255000 rows to geography_mappings
# Copied 260000 rows to geography_mappings
# Copied 265000 rows to geography_mappings
# Copied 270000 rows to geography_mappings
# Copied 275000 rows to geography_mappings
# Copied 280000 rows to geography_mappings
# Copied 285000 rows to geography_mappings
# Copied 290000 rows to geography_mappings
# Copied 295000 rows to geography_mappings
# Copied 300000 rows to geography_mappings
# Copied 305000 rows to geography_mappings
# Copied 310000 rows to geography_mappings
# Copied 315000 rows to geography_mappings
# Copied 320000 rows to geography_mappings
# Copied 325000 rows to geography_mappings
# Copied 330000 rows to geography_mappings
# Copied 335000 rows to geography_mappings
# Copied 340000 rows to geography_mappings
# Copied 345000 rows to geography_mappings
# Copied 350000 rows to geography_mappings
# Copied 355000 rows to geography_mappings
# Copied 360000 rows to geography_mappings
# Copied 365000 rows to geography_mappings
# Copied 370000 rows to geography_mappings
# Copied 375000 rows to geography_mappings
# Copied 380000 rows to geography_mappings
# Copied 385000 rows to geography_mappings
# Copied 390000 rows to geography_mappings
# Copied 395000 rows to geography_mappings
# Copied 400000 rows to geography_mappings
# Copied 405000 rows to geography_mappings
# Copied 410000 rows to geography_mappings
# Copied 415000 rows to geography_mappings
# Copied 420000 rows to geography_mappings
# Copied 425000 rows to geography_mappings
# Copied 430000 rows to geography_mappings
# Copied 435000 rows to geography_mappings
# Copied 440000 rows to geography_mappings
# Copied 445000 rows to geography_mappings
# Copied 450000 rows to geography_mappings
# Copied 455000 rows to geography_mappings
# Copied 460000 rows to geography_mappings
# Copied 465000 rows to geography_mappings
# Copied 470000 rows to geography_mappings
# Copied 475000 rows to geography_mappings
# Copied 480000 rows to geography_mappings
# Copied 485000 rows to geography_mappings
# Copied 490000 rows to geography_mappings
# Copied 495000 rows to geography_mappings
# Copied 500000 rows to geography_mappings
# Copied 505000 rows to geography_mappings
# Copied 510000 rows to geography_mappings
# Copied 515000 rows to geography_mappings
# Copied 520000 rows to geography_mappings
# Copied 525000 rows to geography_mappings
# Copied 530000 rows to geography_mappings
# Copied 535000 rows to geography_mappings
# Copied 540000 rows to geography_mappings
# Copied 545000 rows to geography_mappings
# Copied 550000 rows to geography_mappings
# Copied 555000 rows to geography_mappings
# Copied 560000 rows to geography_mappings
# Copied 565000 rows to geography_mappings
# Copied 570000 rows to geography_mappings
# Copied 575000 rows to geography_mappings
# Copied 580000 rows to geography_mappings
# Copied 585000 rows to geography_mappings
# Copied 590000 rows to geography_mappings
# Copied 595000 rows to geography_mappings
# Copied 600000 rows to geography_mappings
# Copied 605000 rows to geography_mappings
# Copied 610000 rows to geography_mappings
# Copied 615000 rows to geography_mappings
# Copied 620000 rows to geography_mappings
# Copied 625000 rows to geography_mappings
# Copied 630000 rows to geography_mappings
# Copied 635000 rows to geography_mappings
# Copied 640000 rows to geography_mappings
# Copied 645000 rows to geography_mappings
# Copied 650000 rows to geography_mappings
# Copied 655000 rows to geography_mappings
# Copied 660000 rows to geography_mappings
# Copied 665000 rows to geography_mappings
# Copied 670000 rows to geography_mappings
# Copied 675000 rows to geography_mappings
# Copied 680000 rows to geography_mappings
# Copied 685000 rows to geography_mappings
# Copied 690000 rows to geography_mappings
# Copied 695000 rows to geography_mappings
# Copied 700000 rows to geography_mappings
# Copied 705000 rows to geography_mappings
# Copied 710000 rows to geography_mappings
# Copied 715000 rows to geography_mappings
# Copied 720000 rows to geography_mappings
# Copied 725000 rows to geography_mappings
# Copied 730000 rows to geography_mappings
# Copied 735000 rows to geography_mappings
# Copied 740000 rows to geography_mappings
# Copied 745000 rows to geography_mappings
# Copied 750000 rows to geography_mappings
# Copied 755000 rows to geography_mappings
# Copied 760000 rows to geography_mappings
# Copied 765000 rows to geography_mappings
# Copied 770000 rows to geography_mappings
# Copied 775000 rows to geography_mappings
# Copied 780000 rows to geography_mappings
# Copied 785000 rows to geography_mappings
# Copied 790000 rows to geography_mappings
# Copied 795000 rows to geography_mappings
# Copied 800000 rows to geography_mappings
# Copied 805000 rows to geography_mappings
# Copied 810000 rows to geography_mappings
# Copied 815000 rows to geography_mappings
# Copied 820000 rows to geography_mappings
# Copied 825000 rows to geography_mappings
# Copied 830000 rows to geography_mappings
# Copied 835000 rows to geography_mappings
# Copied 840000 rows to geography_mappings
# Copied 845000 rows to geography_mappings
# Copied 850000 rows to geography_mappings
# Copied 855000 rows to geography_mappings
# Copied 860000 rows to geography_mappings
# Copied 865000 rows to geography_mappings
# Copied 870000 rows to geography_mappings
# Copied 875000 rows to geography_mappings
# Copied 880000 rows to geography_mappings
# Copied 885000 rows to geography_mappings
# Copied 890000 rows to geography_mappings
# Copied 895000 rows to geography_mappings
# Copied 900000 rows to geography_mappings
# Copied 905000 rows to geography_mappings
# Copied 910000 rows to geography_mappings
# Copied 915000 rows to geography_mappings
# Copied 920000 rows to geography_mappings
# Copied 925000 rows to geography_mappings
# Copied 930000 rows to geography_mappings
# Copied 935000 rows to geography_mappings
# Copied 940000 rows to geography_mappings
# Copied 945000 rows to geography_mappings
# Copied 950000 rows to geography_mappings
# Copied 955000 rows to geography_mappings
# Copied 960000 rows to geography_mappings
# Copied 965000 rows to geography_mappings
# Copied 970000 rows to geography_mappings
# Copied 975000 rows to geography_mappings
# Copied 980000 rows to geography_mappings
# Copied 985000 rows to geography_mappings
# Copied 990000 rows to geography_mappings
# Copied 995000 rows to geography_mappings
# Copied 1000000 rows to geography_mappings
# Copied 1005000 rows to geography_mappings
# Copied 1010000 rows to geography_mappings
# Copied 1015000 rows to geography_mappings
# Copied 1020000 rows to geography_mappings
# Copied 1025000 rows to geography_mappings
# Copied 1030000 rows to geography_mappings
# Copied 1035000 rows to geography_mappings
# Copied 1040000 rows to geography_mappings
# Copied 1045000 rows to geography_mappings
# Copied 1050000 rows to geography_mappings
# Copied 1055000 rows to geography_mappings
# Copied 1060000 rows to geography_mappings
# Copied 1065000 rows to geography_mappings
# Copied 1070000 rows to geography_mappings
# Copied 1075000 rows to geography_mappings
# Copied 1080000 rows to geography_mappings
# Copied 1085000 rows to geography_mappings
# Copied 1090000 rows to geography_mappings
# Copied 1095000 rows to geography_mappings
# Copied 1100000 rows to geography_mappings
# Copied 1105000 rows to geography_mappings
# Copied 1110000 rows to geography_mappings
# Copied 1115000 rows to geography_mappings
# Copied 1120000 rows to geography_mappings
# Copied 1125000 rows to geography_mappings
# Copied 1130000 rows to geography_mappings
# Copied 1135000 rows to geography_mappings
# Copied 1140000 rows to geography_mappings
# Copied 1145000 rows to geography_mappings
# Copied 1150000 rows to geography_mappings
# Copied 1155000 rows to geography_mappings
# Copied 1160000 rows to geography_mappings
# Copied 1165000 rows to geography_mappings
# Copied 1170000 rows to geography_mappings
# Copied 1175000 rows to geography_mappings
# Copied 1180000 rows to geography_mappings
# Copied 1185000 rows to geography_mappings
# Copied 1190000 rows to geography_mappings
# Copied 1195000 rows to geography_mappings
# Copied 1200000 rows to geography_mappings
# Copied 1205000 rows to geography_mappings
# Copied 1210000 rows to geography_mappings
# Copied 1215000 rows to geography_mappings
# Copied 1220000 rows to geography_mappings
# Copied 1225000 rows to geography_mappings
# Copied 1230000 rows to geography_mappings
# Copied 1235000 rows to geography_mappings
# Copied 1240000 rows to geography_mappings
# Copied 1245000 rows to geography_mappings
# Copied 1250000 rows to geography_mappings
# Copied 1255000 rows to geography_mappings
# Copied 1260000 rows to geography_mappings
# Copied 1265000 rows to geography_mappings
# Copied 1270000 rows to geography_mappings
# Copied 1275000 rows to geography_mappings
# Copied 1280000 rows to geography_mappings
# Copied 1285000 rows to geography_mappings
# Copied 1290000 rows to geography_mappings
# Copied 1295000 rows to geography_mappings
# Copied 1300000 rows to geography_mappings
# Copied 1305000 rows to geography_mappings
# Copied 1310000 rows to geography_mappings
# Copied 1315000 rows to geography_mappings
# Copied 1320000 rows to geography_mappings
# Copied 1325000 rows to geography_mappings
# Copied 1330000 rows to geography_mappings
# Copied 1335000 rows to geography_mappings
# Copied 1340000 rows to geography_mappings
# Copied 1345000 rows to geography_mappings
# Copied 1350000 rows to geography_mappings
# Copied 1355000 rows to geography_mappings
# Copied 1360000 rows to geography_mappings
# Copied 1365000 rows to geography_mappings
# Copied 1370000 rows to geography_mappings
# Copied 1375000 rows to geography_mappings
# Copied 1380000 rows to geography_mappings
# Copied 1385000 rows to geography_mappings
# Copied 1390000 rows to geography_mappings
# Copied 1395000 rows to geography_mappings
# Copied 1400000 rows to geography_mappings
# Copied 1405000 rows to geography_mappings
# Copied 1410000 rows to geography_mappings
# Copied 1415000 rows to geography_mappings
# Copied 1420000 rows to geography_mappings
# Copied 1425000 rows to geography_mappings
# Copied 1430000 rows to geography_mappings
# Copied 1435000 rows to geography_mappings
# Copied 1440000 rows to geography_mappings
# Copied 1445000 rows to geography_mappings
# Copied 1450000 rows to geography_mappings
# Copied 1455000 rows to geography_mappings
# Copied 1460000 rows to geography_mappings
# Copied 1465000 rows to geography_mappings
# Copied 1470000 rows to geography_mappings
# Copied 1475000 rows to geography_mappings
# Copied 1480000 rows to geography_mappings
# Copied 1485000 rows to geography_mappings
# Copied 1490000 rows to geography_mappings
# Copied 1495000 rows to geography_mappings
# Copied 1500000 rows to geography_mappings
# Copied 1505000 rows to geography_mappings
# Copied 1510000 rows to geography_mappings
# Copied 1515000 rows to geography_mappings
# Copied 1520000 rows to geography_mappings
# Copied 1525000 rows to geography_mappings
# Copied 1530000 rows to geography_mappings
# Copied 1535000 rows to geography_mappings
# Copied 1540000 rows to geography_mappings
# Copied 1545000 rows to geography_mappings
# Copied 1550000 rows to geography_mappings
# Copied 1555000 rows to geography_mappings
# Copied 1560000 rows to geography_mappings
# Copied 1565000 rows to geography_mappings
# Copied 1570000 rows to geography_mappings
# Copied 1575000 rows to geography_mappings
# Copied 1580000 rows to geography_mappings
# Copied 1585000 rows to geography_mappings
# Copied 1590000 rows to geography_mappings
# Copied 1595000 rows to geography_mappings
# Copied 1600000 rows to geography_mappings
# Copied 1605000 rows to geography_mappings
# Copied 1610000 rows to geography_mappings
# Copied 1615000 rows to geography_mappings
# Copied 1620000 rows to geography_mappings
# Copied 1625000 rows to geography_mappings
# Copied 1630000 rows to geography_mappings
# Copied 1635000 rows to geography_mappings
# Copied 1640000 rows to geography_mappings
# Copied 1645000 rows to geography_mappings
# Copied 1650000 rows to geography_mappings
# Copied 1655000 rows to geography_mappings
# Copied 1660000 rows to geography_mappings
# Copied 1665000 rows to geography_mappings
# Copied 1670000 rows to geography_mappings
# Copied 1675000 rows to geography_mappings
# Copied 1680000 rows to geography_mappings
# Copied 1685000 rows to geography_mappings
# Copied 1690000 rows to geography_mappings
# Copied 1695000 rows to geography_mappings
# Copied 1700000 rows to geography_mappings
# Copied 1705000 rows to geography_mappings
# Copied 1710000 rows to geography_mappings
# Copied 1715000 rows to geography_mappings
# Copied 1720000 rows to geography_mappings
# Copied 1725000 rows to geography_mappings
# Copied 1730000 rows to geography_mappings
# Copied 1735000 rows to geography_mappings
# Copied 1740000 rows to geography_mappings
# Copied 1745000 rows to geography_mappings
# Copied 1750000 rows to geography_mappings
# Copied 1755000 rows to geography_mappings
# Copied 1760000 rows to geography_mappings
# Copied 1765000 rows to geography_mappings
# Copied 1770000 rows to geography_mappings
# Copied 1775000 rows to geography_mappings
# Copied 1780000 rows to geography_mappings
# Copied 1785000 rows to geography_mappings
# Copied 1790000 rows to geography_mappings
# Copied 1795000 rows to geography_mappings
# Copied 1800000 rows to geography_mappings
# Copied 1805000 rows to geography_mappings
# Copied 1810000 rows to geography_mappings
# Copied 1815000 rows to geography_mappings
# Copied 1820000 rows to geography_mappings
# Copied 1825000 rows to geography_mappings
# Copied 1830000 rows to geography_mappings
# Copied 1835000 rows to geography_mappings
# Copied 1840000 rows to geography_mappings
# Copied 1845000 rows to geography_mappings
# Copied 1850000 rows to geography_mappings
# Copied 1855000 rows to geography_mappings
# Copied 1860000 rows to geography_mappings
# Copied 1865000 rows to geography_mappings
# Copied 1870000 rows to geography_mappings
# Copied 1875000 rows to geography_mappings
# Copied 1880000 rows to geography_mappings
# Copied 1885000 rows to geography_mappings
# Copied 1890000 rows to geography_mappings
# Copied 1895000 rows to geography_mappings
# Copied 1900000 rows to geography_mappings
# Copied 1905000 rows to geography_mappings
# Copied 1910000 rows to geography_mappings
# Copied 1915000 rows to geography_mappings
# Copied 1920000 rows to geography_mappings
# Copied 1925000 rows to geography_mappings
# Copied 1930000 rows to geography_mappings
# Copied 1935000 rows to geography_mappings
# Copied 1940000 rows to geography_mappings
# Copied 1945000 rows to geography_mappings
# Copied 1950000 rows to geography_mappings
# Copied 1955000 rows to geography_mappings
# Copied 1960000 rows to geography_mappings
# Copied 1965000 rows to geography_mappings
# Copied 1970000 rows to geography_mappings
# Copied 1975000 rows to geography_mappings
# Copied 1980000 rows to geography_mappings
# Copied 1985000 rows to geography_mappings
# Copied 1990000 rows to geography_mappings
# Copied 1995000 rows to geography_mappings
# Copied 2000000 rows to geography_mappings
# Copied 2005000 rows to geography_mappings
# Copied 2010000 rows to geography_mappings
# Copied 2015000 rows to geography_mappings
# Copied 2020000 rows to geography_mappings
# Copied 2025000 rows to geography_mappings
# Copied 2030000 rows to geography_mappings
# Copied 2035000 rows to geography_mappings
# Copied 2040000 rows to geography_mappings
# Copied 2045000 rows to geography_mappings
# Copied 2050000 rows to geography_mappings
# Copied 2055000 rows to geography_mappings
# Copied 2060000 rows to geography_mappings
# Copied 2065000 rows to geography_mappings
# Copied 2070000 rows to geography_mappings
# Copied 2075000 rows to geography_mappings
# Copied 2080000 rows to geography_mappings
# Copied 2085000 rows to geography_mappings
# Copied 2090000 rows to geography_mappings
# Copied 2095000 rows to geography_mappings
# Copied 2100000 rows to geography_mappings
# Copied 2105000 rows to geography_mappings
# Copied 2110000 rows to geography_mappings
# Copied 2115000 rows to geography_mappings
# Copied 2120000 rows to geography_mappings
# Copied 2125000 rows to geography_mappings
# Copied 2130000 rows to geography_mappings
# Copied 2135000 rows to geography_mappings
# Copied 2140000 rows to geography_mappings
# Copied 2145000 rows to geography_mappings
# Copied 2150000 rows to geography_mappings
# Copied 2155000 rows to geography_mappings
# Copied 2160000 rows to geography_mappings
# Copied 2165000 rows to geography_mappings
# Copied 2170000 rows to geography_mappings
# Copied 2175000 rows to geography_mappings
# Copied 2180000 rows to geography_mappings
# Copied 2185000 rows to geography_mappings
# Copied 2190000 rows to geography_mappings
# Copied 2195000 rows to geography_mappings
# Copied 2200000 rows to geography_mappings
# Copied 2205000 rows to geography_mappings
# Copied 2210000 rows to geography_mappings
# Copied 2215000 rows to geography_mappings
# Copied 2220000 rows to geography_mappings
# Copied 2225000 rows to geography_mappings
# Copied 2230000 rows to geography_mappings
# Copied 2235000 rows to geography_mappings
# Copied 2240000 rows to geography_mappings
# Copied 2245000 rows to geography_mappings
# Copied 2250000 rows to geography_mappings
# Copied 2255000 rows to geography_mappings
# Copied 2260000 rows to geography_mappings
# Copied 2265000 rows to geography_mappings
# Copied 2270000 rows to geography_mappings
# Copied 2275000 rows to geography_mappings
# Copied 2280000 rows to geography_mappings
# Copied 2285000 rows to geography_mappings
# Copied 2290000 rows to geography_mappings
# Copied 2295000 rows to geography_mappings
# Copied 2300000 rows to geography_mappings
# Copied 2305000 rows to geography_mappings
# Copied 2310000 rows to geography_mappings
# Copied 2315000 rows to geography_mappings
# Copied 2320000 rows to geography_mappings
# Copied 2325000 rows to geography_mappings
# Copied 2330000 rows to geography_mappings
# Copied 2335000 rows to geography_mappings
# Copied 2340000 rows to geography_mappings
# Copied 2345000 rows to geography_mappings
# Copied 2350000 rows to geography_mappings
# Copied 2352552 rows to geography_mappings
# Columns copied successfully from local to remote 'geography_mappings' table.

# %%
import psycopg2
from psycopg2 import sql
from dotenv import load_dotenv
import io

# Load environment variables from .env file
load_dotenv()

# Local database connection parameters
LOCAL_DB_HOST = 'localhost'
LOCAL_DB_PORT = '5432'
LOCAL_DB_USER = 'cardigan'
LOCAL_DB_NAME = 'asylum-seekers'

# Remote database connection URL
REMOTE_DATABASE_URL = "postgres://udvgghkgvhno05:pdb4ac0e3d9341327385cc1514256906b3ea3cee34a8bfca9f9878e3ecb829408@c6i386kdr73gcp.cluster-czz5s0kz4scl.eu-west-1.rds.amazonaws.com:5432/d3p1stj7ab710b"

# Connect to the local database
local_conn = psycopg2.connect(
    host=LOCAL_DB_HOST,
    port=LOCAL_DB_PORT,
    user=LOCAL_DB_USER,
    dbname=LOCAL_DB_NAME
)
local_cur = local_conn.cursor()

# Connect to the remote database
remote_conn = psycopg2.connect(REMOTE_DATABASE_URL, sslmode='require')
remote_cur = remote_conn.cursor()

def copy_table(table_name, batch_size=5000):
    # Fetch column names from the local table
    local_cur.execute(sql.SQL("SELECT * FROM {} LIMIT 0").format(sql.Identifier(table_name)))
    columns = [desc[0] for desc in local_cur.description]

    # Drop the table in the remote database if it exists
    remote_cur.execute(sql.SQL("DROP TABLE IF EXISTS {}").format(sql.Identifier(table_name)))
    remote_conn.commit()

    # Create the table in the remote database with the same columns as the local table
    local_cur.execute(sql.SQL("SELECT column_name, data_type, character_maximum_length FROM information_schema.columns WHERE table_name = %s"), (table_name,))
    column_definitions = local_cur.fetchall()
    create_query = sql.SQL("CREATE TABLE {} ({})").format(
        sql.Identifier(table_name),
        sql.SQL(', ').join([sql.SQL("{} {}{}").format(
            sql.Identifier(col[0]),
            sql.SQL(col[1]),
            sql.SQL('({})'.format(col[2])) if col[2] else sql.SQL('')
        ) for col in column_definitions])
    )
    remote_cur.execute(create_query)
    remote_conn.commit()

    # Fetch data from the local table in batches
    offset = 0
    while True:
        local_cur.execute(sql.SQL("SELECT {} FROM {} OFFSET %s LIMIT %s").format(
            sql.SQL(', ').join(map(sql.Identifier, columns)),
            sql.Identifier(table_name)
        ), [offset, batch_size])
        rows = local_cur.fetchall()
        if not rows:
            break

        # Format rows and escape special characters
        formatted_rows = []
        for row in rows:
            formatted_row = []
            for value in row:
                if value is None:
                    formatted_value = r'\N'
                else:
                    formatted_value = str(value).replace('\n', '\\n').replace('\t', '\\t').replace('\r', '\\r')
                formatted_row.append(formatted_value)
            formatted_rows.append('\t'.join(formatted_row))

        # Use COPY command to insert data into the remote table
        copy_query = sql.SQL("COPY {} ({}) FROM STDIN WITH (FORMAT CSV, DELIMITER E'\\t', NULL '\\N')").format(
            sql.Identifier(table_name),
            sql.SQL(', ').join(map(sql.Identifier, columns))
        )
        remote_cur.copy_expert(copy_query, io.StringIO('\n'.join(formatted_rows)))
        remote_conn.commit()
        offset += len(rows)
        print(f"Copied {offset} rows to {table_name}")

# Get the list of tables in the local database, excluding 'geography_mappings'
local_cur.execute("SELECT table_name FROM information_schema.tables WHERE table_schema = 'public' AND table_name != 'geography_mappings'")
tables = [row[0] for row in local_cur.fetchall()]

# Copy each table from the local database to the remote database
for table_name in tables:
    print(f"Copying table: {table_name}")
    copy_table(table_name)

# Close the cursors and connections
local_cur.close()
local_conn.close()
remote_cur.close()
remote_conn.close()

print("All tables copied successfully from local to remote database.")
# Out:
# Copying table: census2021-ts003-ctry
# Copied 3 rows to census2021-ts003-ctry
# Copying table: census2021-ts003-ltla
# Copied 331 rows to census2021-ts003-ltla
# Copying table: census2021-ts003-msoa
# Copied 5000 rows to census2021-ts003-msoa
# Copied 7264 rows to census2021-ts003-msoa
# Copying table: census2021-ts003-lsoa
# Copied 5000 rows to census2021-ts003-lsoa
# Copied 10000 rows to census2021-ts003-lsoa
# Copied 15000 rows to census2021-ts003-lsoa
# Copied 20000 rows to census2021-ts003-lsoa
# Copied 25000 rows to census2021-ts003-lsoa
# Copied 30000 rows to census2021-ts003-lsoa
# Copied 35000 rows to census2021-ts003-lsoa
# Copied 35672 rows to census2021-ts003-lsoa
# Copying table: census2021-ts003-rgn
# Copied 10 rows to census2021-ts003-rgn
# Copying table: census2021-ts003-utla
# Copied 174 rows to census2021-ts003-utla
# Copying table: census2021-ts004-msoa
# Copied 5000 rows to census2021-ts004-msoa
# Copied 7264 rows to census2021-ts004-msoa
# Copying table: census2021-ts004-ctry
# Copied 3 rows to census2021-ts004-ctry
# Copying table: census2021-ts005-rgn
# Copied 10 rows to census2021-ts005-rgn
# Copying table: census2021-ts005-ltla
# Copied 331 rows to census2021-ts005-ltla
# Copying table: census2021-ts005-oa
# Copied 5000 rows to census2021-ts005-oa
# Copied 10000 rows to census2021-ts005-oa
# Copied 15000 rows to census2021-ts005-oa
# Copied 20000 rows to census2021-ts005-oa
# Copied 25000 rows to census2021-ts005-oa
# Copied 30000 rows to census2021-ts005-oa
# Copied 35000 rows to census2021-ts005-oa
# Copied 40000 rows to census2021-ts005-oa
# Copied 45000 rows to census2021-ts005-oa
# Copied 50000 rows to census2021-ts005-oa
# Copied 55000 rows to census2021-ts005-oa
# Copied 60000 rows to census2021-ts005-oa
# Copied 65000 rows to census2021-ts005-oa
# Copied 70000 rows to census2021-ts005-oa
# Copied 75000 rows to census2021-ts005-oa
# Copied 80000 rows to census2021-ts005-oa
# Copied 85000 rows to census2021-ts005-oa
# Copied 90000 rows to census2021-ts005-oa
# Copied 95000 rows to census2021-ts005-oa
# Copied 100000 rows to census2021-ts005-oa
# Copied 105000 rows to census2021-ts005-oa
# Copied 110000 rows to census2021-ts005-oa
# Copied 115000 rows to census2021-ts005-oa
# Copied 120000 rows to census2021-ts005-oa
# Copied 125000 rows to census2021-ts005-oa
# Copied 130000 rows to census2021-ts005-oa
# Copied 135000 rows to census2021-ts005-oa
# Copied 140000 rows to census2021-ts005-oa
# Copied 145000 rows to census2021-ts005-oa
# Copied 150000 rows to census2021-ts005-oa
# Copied 155000 rows to census2021-ts005-oa
# Copied 160000 rows to census2021-ts005-oa
# Copied 165000 rows to census2021-ts005-oa
# Copied 170000 rows to census2021-ts005-oa
# Copied 175000 rows to census2021-ts005-oa
# Copied 180000 rows to census2021-ts005-oa
# Copied 185000 rows to census2021-ts005-oa
# Copied 188880 rows to census2021-ts005-oa
# Copying table: column_name_mappings
# Copied 503 rows to column_name_mappings
# Copying table: census2021-ts002-lsoa.
# Copied 5000 rows to census2021-ts002-lsoa.
# Copied 10000 rows to census2021-ts002-lsoa.
# Copied 15000 rows to census2021-ts002-lsoa.
# Copied 20000 rows to census2021-ts002-lsoa.
# Copied 25000 rows to census2021-ts002-lsoa.
# Copied 30000 rows to census2021-ts002-lsoa.
# Copied 35000 rows to census2021-ts002-lsoa.
# Copied 35672 rows to census2021-ts002-lsoa.
# Copying table: census2021-ts002-ctry
# Copied 3 rows to census2021-ts002-ctry
# Copying table: census2021-ts002-rgn
# Copied 10 rows to census2021-ts002-rgn
# Copying table: census2021-ts002-ltla
# Copied 331 rows to census2021-ts002-ltla
# Copying table: census2021-ts002-msoa.
# Copied 5000 rows to census2021-ts002-msoa.
# Copied 7264 rows to census2021-ts002-msoa.
# Copying table: census2021-ts002-oa
# Copied 5000 rows to census2021-ts002-oa
# Copied 10000 rows to census2021-ts002-oa
# Copied 15000 rows to census2021-ts002-oa
# Copied 20000 rows to census2021-ts002-oa
# Copied 25000 rows to census2021-ts002-oa
# Copied 30000 rows to census2021-ts002-oa
# Copied 35000 rows to census2021-ts002-oa
# Copied 40000 rows to census2021-ts002-oa
# Copied 45000 rows to census2021-ts002-oa
# Copied 50000 rows to census2021-ts002-oa
# Copied 55000 rows to census2021-ts002-oa
# Copied 60000 rows to census2021-ts002-oa
# Copied 65000 rows to census2021-ts002-oa
# Copied 70000 rows to census2021-ts002-oa
# Copied 75000 rows to census2021-ts002-oa
# Copied 80000 rows to census2021-ts002-oa
# Copied 85000 rows to census2021-ts002-oa
# Copied 90000 rows to census2021-ts002-oa
# Copied 95000 rows to census2021-ts002-oa
# Copied 100000 rows to census2021-ts002-oa
# Copied 105000 rows to census2021-ts002-oa
# Copied 110000 rows to census2021-ts002-oa
# Copied 115000 rows to census2021-ts002-oa
# Copied 120000 rows to census2021-ts002-oa
# Copied 125000 rows to census2021-ts002-oa
# Copied 130000 rows to census2021-ts002-oa
# Copied 135000 rows to census2021-ts002-oa
# Copied 140000 rows to census2021-ts002-oa
# Copied 145000 rows to census2021-ts002-oa
# Copied 150000 rows to census2021-ts002-oa
# Copied 155000 rows to census2021-ts002-oa
# Copied 160000 rows to census2021-ts002-oa
# Copied 165000 rows to census2021-ts002-oa
# Copied 170000 rows to census2021-ts002-oa
# Copied 175000 rows to census2021-ts002-oa
# Copied 180000 rows to census2021-ts002-oa
# Copied 185000 rows to census2021-ts002-oa
# Copied 188880 rows to census2021-ts002-oa
# Copying table: census2021-ts002-utla
# Copied 174 rows to census2021-ts002-utla
# Copying table: census2021-ts001-utla
# Copied 174 rows to census2021-ts001-utla
# Copying table: census2021-ts001-lsoa
# Copied 5000 rows to census2021-ts001-lsoa
# Copied 10000 rows to census2021-ts001-lsoa
# Copied 15000 rows to census2021-ts001-lsoa
# Copied 20000 rows to census2021-ts001-lsoa
# Copied 25000 rows to census2021-ts001-lsoa
# Copied 30000 rows to census2021-ts001-lsoa
# Copied 35000 rows to census2021-ts001-lsoa
# Copied 35672 rows to census2021-ts001-lsoa
# Copying table: census2021-ts005-msoa
# Copied 5000 rows to census2021-ts005-msoa
# Copied 7264 rows to census2021-ts005-msoa
# Copying table: census2021-ts005-ctry
# Copied 3 rows to census2021-ts005-ctry
# Copying table: census2021-ts005-lsoa
# Copied 5000 rows to census2021-ts005-lsoa
# Copied 10000 rows to census2021-ts005-lsoa
# Copied 15000 rows to census2021-ts005-lsoa
# Copied 20000 rows to census2021-ts005-lsoa
# Copied 25000 rows to census2021-ts005-lsoa
# Copied 30000 rows to census2021-ts005-lsoa
# Copied 35000 rows to census2021-ts005-lsoa
# Copied 35672 rows to census2021-ts005-lsoa
# Copying table: census2021-ts005-utla
# Copied 174 rows to census2021-ts005-utla
# Copying table: census2021-ts004-ulta
# Copied 174 rows to census2021-ts004-ulta
# Copying table: census2021-ts001-oa
# Copied 5000 rows to census2021-ts001-oa
# Copied 10000 rows to census2021-ts001-oa
# Copied 15000 rows to census2021-ts001-oa
# Copied 20000 rows to census2021-ts001-oa
# Copied 25000 rows to census2021-ts001-oa
# Copied 30000 rows to census2021-ts001-oa
# Copied 35000 rows to census2021-ts001-oa
# Copied 40000 rows to census2021-ts001-oa
# Copied 45000 rows to census2021-ts001-oa
# Copied 50000 rows to census2021-ts001-oa
# Copied 55000 rows to census2021-ts001-oa
# Copied 60000 rows to census2021-ts001-oa
# Copied 65000 rows to census2021-ts001-oa
# Copied 70000 rows to census2021-ts001-oa
# Copied 75000 rows to census2021-ts001-oa
# Copied 80000 rows to census2021-ts001-oa
# Copied 85000 rows to census2021-ts001-oa
# Copied 90000 rows to census2021-ts001-oa
# Copied 95000 rows to census2021-ts001-oa
# Copied 100000 rows to census2021-ts001-oa
# Copied 105000 rows to census2021-ts001-oa
# Copied 110000 rows to census2021-ts001-oa
# Copied 115000 rows to census2021-ts001-oa
# Copied 120000 rows to census2021-ts001-oa
# Copied 125000 rows to census2021-ts001-oa
# Copied 130000 rows to census2021-ts001-oa
# Copied 135000 rows to census2021-ts001-oa
# Copied 140000 rows to census2021-ts001-oa
# Copied 145000 rows to census2021-ts001-oa
# Copied 150000 rows to census2021-ts001-oa
# Copied 155000 rows to census2021-ts001-oa
# Copied 160000 rows to census2021-ts001-oa
# Copied 165000 rows to census2021-ts001-oa
# Copied 170000 rows to census2021-ts001-oa
# Copied 175000 rows to census2021-ts001-oa
# Copied 180000 rows to census2021-ts001-oa
# Copied 185000 rows to census2021-ts001-oa
# Copied 188880 rows to census2021-ts001-oa
# Copying table: census2021-ts001-msoa
# Copied 5000 rows to census2021-ts001-msoa
# Copied 7264 rows to census2021-ts001-msoa
# Copying table: census2021-ts001-ltla
# Copied 331 rows to census2021-ts001-ltla
# Copying table: census2021-ts001-ctry
# Copied 3 rows to census2021-ts001-ctry
# Copying table: census2021-ts001-rgn
# Copied 10 rows to census2021-ts001-rgn
# Copying table: schema_descriptions
# Copied 34 rows to schema_descriptions
# Copying table: census2021-ts003-oa
# Copied 5000 rows to census2021-ts003-oa
# Copied 10000 rows to census2021-ts003-oa
# Copied 15000 rows to census2021-ts003-oa
# Copied 20000 rows to census2021-ts003-oa
# Copied 25000 rows to census2021-ts003-oa
# Copied 30000 rows to census2021-ts003-oa
# Copied 35000 rows to census2021-ts003-oa
# Copied 40000 rows to census2021-ts003-oa
# Copied 45000 rows to census2021-ts003-oa
# Copied 50000 rows to census2021-ts003-oa
# Copied 55000 rows to census2021-ts003-oa
# Copied 60000 rows to census2021-ts003-oa
# Copied 65000 rows to census2021-ts003-oa
# Copied 70000 rows to census2021-ts003-oa
# Copied 75000 rows to census2021-ts003-oa
# Copied 80000 rows to census2021-ts003-oa
# Copied 85000 rows to census2021-ts003-oa
# Copied 90000 rows to census2021-ts003-oa
# Copied 95000 rows to census2021-ts003-oa
# Copied 100000 rows to census2021-ts003-oa
# Copied 105000 rows to census2021-ts003-oa
# Copied 110000 rows to census2021-ts003-oa
# Copied 115000 rows to census2021-ts003-oa
# Copied 120000 rows to census2021-ts003-oa
# Copied 125000 rows to census2021-ts003-oa
# Copied 130000 rows to census2021-ts003-oa
# Copied 135000 rows to census2021-ts003-oa
# Copied 140000 rows to census2021-ts003-oa
# Copied 145000 rows to census2021-ts003-oa
# Copied 150000 rows to census2021-ts003-oa
# Copied 155000 rows to census2021-ts003-oa
# Copied 160000 rows to census2021-ts003-oa
# Copied 165000 rows to census2021-ts003-oa
# Copied 170000 rows to census2021-ts003-oa
# Copied 175000 rows to census2021-ts003-oa
# Copied 180000 rows to census2021-ts003-oa
# Copied 185000 rows to census2021-ts003-oa
# Copied 188880 rows to census2021-ts003-oa
# Copying table: census2021-ts004-llta
# Copied 331 rows to census2021-ts004-llta
# Copying table: census2021-ts004-rgn
# Copied 10 rows to census2021-ts004-rgn
# Copying table: census2021-ts004-lsoa
# Copied 5000 rows to census2021-ts004-lsoa
# Copied 10000 rows to census2021-ts004-lsoa
# Copied 15000 rows to census2021-ts004-lsoa
# Copied 20000 rows to census2021-ts004-lsoa
# Copied 25000 rows to census2021-ts004-lsoa
# Copied 30000 rows to census2021-ts004-lsoa
# Copied 35000 rows to census2021-ts004-lsoa
# Copied 35672 rows to census2021-ts004-lsoa
# Copying table: census2021-ts004-oa
# Copied 5000 rows to census2021-ts004-oa
# Copied 10000 rows to census2021-ts004-oa
# Copied 15000 rows to census2021-ts004-oa
# Copied 20000 rows to census2021-ts004-oa
# Copied 25000 rows to census2021-ts004-oa
# Copied 30000 rows to census2021-ts004-oa
# Copied 35000 rows to census2021-ts004-oa
# Copied 40000 rows to census2021-ts004-oa
# Copied 45000 rows to census2021-ts004-oa
# Copied 50000 rows to census2021-ts004-oa
# Copied 55000 rows to census2021-ts004-oa
# Copied 60000 rows to census2021-ts004-oa
# Copied 65000 rows to census2021-ts004-oa
# Copied 70000 rows to census2021-ts004-oa
# Copied 75000 rows to census2021-ts004-oa
# Copied 80000 rows to census2021-ts004-oa
# Copied 85000 rows to census2021-ts004-oa
# Copied 90000 rows to census2021-ts004-oa
# Copied 95000 rows to census2021-ts004-oa
# Copied 100000 rows to census2021-ts004-oa
# Copied 105000 rows to census2021-ts004-oa
# Copied 110000 rows to census2021-ts004-oa
# Copied 115000 rows to census2021-ts004-oa
# Copied 120000 rows to census2021-ts004-oa
# Copied 125000 rows to census2021-ts004-oa
# Copied 130000 rows to census2021-ts004-oa
# Copied 135000 rows to census2021-ts004-oa
# Copied 140000 rows to census2021-ts004-oa
# Copied 145000 rows to census2021-ts004-oa
# Copied 150000 rows to census2021-ts004-oa
# Copied 155000 rows to census2021-ts004-oa
# Copied 160000 rows to census2021-ts004-oa
# Copied 165000 rows to census2021-ts004-oa
# Copied 170000 rows to census2021-ts004-oa
# Copied 175000 rows to census2021-ts004-oa
# Copied 180000 rows to census2021-ts004-oa
# Copied 185000 rows to census2021-ts004-oa
# Copied 188880 rows to census2021-ts004-oa
# Copying table: census2021-ts019-ctry
# Copied 3 rows to census2021-ts019-ctry
# Copying table: census2021-ts019-msoa
# Copied 5000 rows to census2021-ts019-msoa
# Copied 7264 rows to census2021-ts019-msoa
# Copying table: census2021-ts019-oa
# Copied 5000 rows to census2021-ts019-oa
# Copied 10000 rows to census2021-ts019-oa
# Copied 15000 rows to census2021-ts019-oa
# Copied 20000 rows to census2021-ts019-oa
# Copied 25000 rows to census2021-ts019-oa
# Copied 30000 rows to census2021-ts019-oa
# Copied 35000 rows to census2021-ts019-oa
# Copied 40000 rows to census2021-ts019-oa
# Copied 45000 rows to census2021-ts019-oa
# Copied 50000 rows to census2021-ts019-oa
# Copied 55000 rows to census2021-ts019-oa
# Copied 60000 rows to census2021-ts019-oa
# Copied 65000 rows to census2021-ts019-oa
# Copied 70000 rows to census2021-ts019-oa
# Copied 75000 rows to census2021-ts019-oa
# Copied 80000 rows to census2021-ts019-oa
# Copied 85000 rows to census2021-ts019-oa
# Copied 90000 rows to census2021-ts019-oa
# Copied 95000 rows to census2021-ts019-oa
# Copied 100000 rows to census2021-ts019-oa
# Copied 105000 rows to census2021-ts019-oa
# Copied 110000 rows to census2021-ts019-oa
# Copied 115000 rows to census2021-ts019-oa
# Copied 120000 rows to census2021-ts019-oa
# Copied 125000 rows to census2021-ts019-oa
# Copied 130000 rows to census2021-ts019-oa
# Copied 135000 rows to census2021-ts019-oa
# Copied 140000 rows to census2021-ts019-oa
# Copied 145000 rows to census2021-ts019-oa
# Copied 150000 rows to census2021-ts019-oa
# Copied 155000 rows to census2021-ts019-oa
# Copied 160000 rows to census2021-ts019-oa
# Copied 165000 rows to census2021-ts019-oa
# Copied 170000 rows to census2021-ts019-oa
# Copied 175000 rows to census2021-ts019-oa
# Copied 180000 rows to census2021-ts019-oa
# Copied 185000 rows to census2021-ts019-oa
# Copied 188880 rows to census2021-ts019-oa
# Copying table: census2021-ts019-ltla
# Copied 331 rows to census2021-ts019-ltla
# Copying table: census2021-ts019-utla
# Copied 174 rows to census2021-ts019-utla
# Copying table: census2021-ts019-rgn
# Copied 10 rows to census2021-ts019-rgn
# Copying table: census2021-ts019-lsoa
# Copied 5000 rows to census2021-ts019-lsoa
# Copied 10000 rows to census2021-ts019-lsoa
# Copied 15000 rows to census2021-ts019-lsoa
# Copied 20000 rows to census2021-ts019-lsoa
# Copied 25000 rows to census2021-ts019-lsoa
# Copied 30000 rows to census2021-ts019-lsoa
# Copied 35000 rows to census2021-ts019-lsoa
# Copied 35672 rows to census2021-ts019-lsoa
# Copying table: census2021-ts026-ctry
# Copied 3 rows to census2021-ts026-ctry
# Copying table: census2021-ts026-msoa
# Copied 5000 rows to census2021-ts026-msoa
# Copied 7264 rows to census2021-ts026-msoa
# Copying table: census2021-ts026-ltla
# Copied 331 rows to census2021-ts026-ltla
# Copying table: census2021-ts026-oa
# Copied 5000 rows to census2021-ts026-oa
# Copied 10000 rows to census2021-ts026-oa
# Copied 15000 rows to census2021-ts026-oa
# Copied 20000 rows to census2021-ts026-oa
# Copied 25000 rows to census2021-ts026-oa
# Copied 30000 rows to census2021-ts026-oa
# Copied 35000 rows to census2021-ts026-oa
# Copied 40000 rows to census2021-ts026-oa
# Copied 45000 rows to census2021-ts026-oa
# Copied 50000 rows to census2021-ts026-oa
# Copied 55000 rows to census2021-ts026-oa
# Copied 60000 rows to census2021-ts026-oa
# Copied 65000 rows to census2021-ts026-oa
# Copied 70000 rows to census2021-ts026-oa
# Copied 75000 rows to census2021-ts026-oa
# Copied 80000 rows to census2021-ts026-oa
# Copied 85000 rows to census2021-ts026-oa
# Copied 90000 rows to census2021-ts026-oa
# Copied 95000 rows to census2021-ts026-oa
# Copied 100000 rows to census2021-ts026-oa
# Copied 105000 rows to census2021-ts026-oa
# Copied 110000 rows to census2021-ts026-oa
# Copied 115000 rows to census2021-ts026-oa
# Copied 120000 rows to census2021-ts026-oa
# Copied 125000 rows to census2021-ts026-oa
# Copied 130000 rows to census2021-ts026-oa
# Copied 135000 rows to census2021-ts026-oa
# Copied 140000 rows to census2021-ts026-oa
# Copied 145000 rows to census2021-ts026-oa
# Copied 150000 rows to census2021-ts026-oa
# Copied 155000 rows to census2021-ts026-oa
# Copied 160000 rows to census2021-ts026-oa
# Copied 165000 rows to census2021-ts026-oa
# Copied 170000 rows to census2021-ts026-oa
# Copied 175000 rows to census2021-ts026-oa
# Copied 180000 rows to census2021-ts026-oa
# Copied 185000 rows to census2021-ts026-oa
# Copied 188880 rows to census2021-ts026-oa
# Copying table: census2021-ts026-rgn
# Copied 10 rows to census2021-ts026-rgn
# Copying table: census2021-ts026-utla
# Copied 174 rows to census2021-ts026-utla
# Copying table: census2021-ts026-lsoa
# Copied 5000 rows to census2021-ts026-lsoa
# Copied 10000 rows to census2021-ts026-lsoa
# Copied 15000 rows to census2021-ts026-lsoa
# Copied 20000 rows to census2021-ts026-lsoa
# Copied 25000 rows to census2021-ts026-lsoa
# Copied 30000 rows to census2021-ts026-lsoa
# Copied 35000 rows to census2021-ts026-lsoa
# Copied 35672 rows to census2021-ts026-lsoa
# Copying table: census2021-ts021-msoa
# Copied 5000 rows to census2021-ts021-msoa
# Copied 7264 rows to census2021-ts021-msoa
# Copying table: census2021-ts021-ltla
# Copied 331 rows to census2021-ts021-ltla
# Copying table: census2021-ts021-ctry
# Copied 3 rows to census2021-ts021-ctry
# Copying table: census2021-ts021-oa
# Copied 5000 rows to census2021-ts021-oa
# Copied 10000 rows to census2021-ts021-oa
# Copied 15000 rows to census2021-ts021-oa
# Copied 20000 rows to census2021-ts021-oa
# Copied 25000 rows to census2021-ts021-oa
# Copied 30000 rows to census2021-ts021-oa
# Copied 35000 rows to census2021-ts021-oa
# Copied 40000 rows to census2021-ts021-oa
# Copied 45000 rows to census2021-ts021-oa
# Copied 50000 rows to census2021-ts021-oa
# Copied 55000 rows to census2021-ts021-oa
# Copied 60000 rows to census2021-ts021-oa
# Copied 65000 rows to census2021-ts021-oa
# Copied 70000 rows to census2021-ts021-oa
# Copied 75000 rows to census2021-ts021-oa
# Copied 80000 rows to census2021-ts021-oa
# Copied 85000 rows to census2021-ts021-oa
# Copied 90000 rows to census2021-ts021-oa
# Copied 95000 rows to census2021-ts021-oa
# Copied 100000 rows to census2021-ts021-oa
# Copied 105000 rows to census2021-ts021-oa
# Copied 110000 rows to census2021-ts021-oa
# Copied 115000 rows to census2021-ts021-oa
# Copied 120000 rows to census2021-ts021-oa
# Copied 125000 rows to census2021-ts021-oa
# Copied 130000 rows to census2021-ts021-oa
# Copied 135000 rows to census2021-ts021-oa
# Copied 140000 rows to census2021-ts021-oa
# Copied 145000 rows to census2021-ts021-oa
# Copied 150000 rows to census2021-ts021-oa
# Copied 155000 rows to census2021-ts021-oa
# Copied 160000 rows to census2021-ts021-oa
# Copied 165000 rows to census2021-ts021-oa
# Copied 170000 rows to census2021-ts021-oa
# Copied 175000 rows to census2021-ts021-oa
# Copied 180000 rows to census2021-ts021-oa
# Copied 185000 rows to census2021-ts021-oa
# Copied 188880 rows to census2021-ts021-oa
# Copying table: census2021-ts021-rgn
# Copied 10 rows to census2021-ts021-rgn
# Copying table: census2021-ts021-utla
# Copied 174 rows to census2021-ts021-utla
# Copying table: census2021-ts021-lsoa
# Copied 5000 rows to census2021-ts021-lsoa
# Copied 10000 rows to census2021-ts021-lsoa
# Copied 15000 rows to census2021-ts021-lsoa
# Copied 20000 rows to census2021-ts021-lsoa
# Copied 25000 rows to census2021-ts021-lsoa
# Copied 30000 rows to census2021-ts021-lsoa
# Copied 35000 rows to census2021-ts021-lsoa
# Copied 35672 rows to census2021-ts021-lsoa
# Copying table: census2021-ts028-utla
# Copied 174 rows to census2021-ts028-utla
# Copying table: census2021-ts028-rgn
# Copied 10 rows to census2021-ts028-rgn
# Copying table: census2021-ts028-ctry
# Copied 3 rows to census2021-ts028-ctry
# Copying table: census2021-ts028-msoa
# Copied 5000 rows to census2021-ts028-msoa
# Copied 7264 rows to census2021-ts028-msoa
# Copying table: census2021-ts028-ltla
# Copied 331 rows to census2021-ts028-ltla
# Copying table: census2021-ts017-lsoa
# Copied 5000 rows to census2021-ts017-lsoa
# Copied 10000 rows to census2021-ts017-lsoa
# Copied 15000 rows to census2021-ts017-lsoa
# Copied 20000 rows to census2021-ts017-lsoa
# Copied 25000 rows to census2021-ts017-lsoa
# Copied 30000 rows to census2021-ts017-lsoa
# Copied 35000 rows to census2021-ts017-lsoa
# Copied 35672 rows to census2021-ts017-lsoa
# Copying table: census2021-ts017-oa
# Copied 5000 rows to census2021-ts017-oa
# Copied 10000 rows to census2021-ts017-oa
# Copied 15000 rows to census2021-ts017-oa
# Copied 20000 rows to census2021-ts017-oa
# Copied 25000 rows to census2021-ts017-oa
# Copied 30000 rows to census2021-ts017-oa
# Copied 35000 rows to census2021-ts017-oa
# Copied 40000 rows to census2021-ts017-oa
# Copied 45000 rows to census2021-ts017-oa
# Copied 50000 rows to census2021-ts017-oa
# Copied 55000 rows to census2021-ts017-oa
# Copied 60000 rows to census2021-ts017-oa
# Copied 65000 rows to census2021-ts017-oa
# Copied 70000 rows to census2021-ts017-oa
# Copied 75000 rows to census2021-ts017-oa
# Copied 80000 rows to census2021-ts017-oa
# Copied 85000 rows to census2021-ts017-oa
# Copied 90000 rows to census2021-ts017-oa
# Copied 95000 rows to census2021-ts017-oa
# Copied 100000 rows to census2021-ts017-oa
# Copied 105000 rows to census2021-ts017-oa
# Copied 110000 rows to census2021-ts017-oa
# Copied 115000 rows to census2021-ts017-oa
# Copied 120000 rows to census2021-ts017-oa
# Copied 125000 rows to census2021-ts017-oa
# Copied 130000 rows to census2021-ts017-oa
# Copied 135000 rows to census2021-ts017-oa
# Copied 140000 rows to census2021-ts017-oa
# Copied 145000 rows to census2021-ts017-oa
# Copied 150000 rows to census2021-ts017-oa
# Copied 155000 rows to census2021-ts017-oa
# Copied 160000 rows to census2021-ts017-oa
# Copied 165000 rows to census2021-ts017-oa
# Copied 170000 rows to census2021-ts017-oa
# Copied 175000 rows to census2021-ts017-oa
# Copied 180000 rows to census2021-ts017-oa
# Copied 185000 rows to census2021-ts017-oa
# Copied 188880 rows to census2021-ts017-oa
# Copying table: census2021-ts017-ulta
# Copied 174 rows to census2021-ts017-ulta
# Copying table: census2021-ts017-rgn
# Copied 10 rows to census2021-ts017-rgn
# Copying table: census2021-ts017-ctry
# Copied 3 rows to census2021-ts017-ctry
# Copying table: census2021-ts017-msoa
# Copied 5000 rows to census2021-ts017-msoa
# Copied 7264 rows to census2021-ts017-msoa
# Copying table: census2021-ts017-ltla
# Copied 331 rows to census2021-ts017-ltla
# Copying table: census2021-ts010-ulta
# Copied 174 rows to census2021-ts010-ulta
# Copying table: census2021-ts010-msoa
# Copied 5000 rows to census2021-ts010-msoa
# Copied 7264 rows to census2021-ts010-msoa
# Copying table: census2021-ts010-ltla
# Copied 331 rows to census2021-ts010-ltla
# Copying table: census2021-ts010-ctry
# Copied 3 rows to census2021-ts010-ctry
# Copying table: census2021-ts010-rgn
# Copied 10 rows to census2021-ts010-rgn
# Copying table: census2021-ts075-ctry
# Copied 3 rows to census2021-ts075-ctry
# Copying table: census2021-ts075-ltla
# Copied 331 rows to census2021-ts075-ltla
# Copying table: census2021-ts075-msoa
# Copied 5000 rows to census2021-ts075-msoa
# Copied 7264 rows to census2021-ts075-msoa
# Copying table: census2021-ts075-rgn
# Copied 10 rows to census2021-ts075-rgn
# Copying table: census2021-ts075-lsoa
# Copied 5000 rows to census2021-ts075-lsoa
# Copied 10000 rows to census2021-ts075-lsoa
# Copied 15000 rows to census2021-ts075-lsoa
# Copied 20000 rows to census2021-ts075-lsoa
# Copied 25000 rows to census2021-ts075-lsoa
# Copied 30000 rows to census2021-ts075-lsoa
# Copied 35000 rows to census2021-ts075-lsoa
# Copied 35672 rows to census2021-ts075-lsoa
# Copying table: census2021-ts075-utla
# Copied 174 rows to census2021-ts075-utla
# Copying table: census2021-ts075-oa
# Copied 5000 rows to census2021-ts075-oa
# Copied 10000 rows to census2021-ts075-oa
# Copied 15000 rows to census2021-ts075-oa
# Copied 20000 rows to census2021-ts075-oa
# Copied 25000 rows to census2021-ts075-oa
# Copied 30000 rows to census2021-ts075-oa
# Copied 35000 rows to census2021-ts075-oa
# Copied 40000 rows to census2021-ts075-oa
# Copied 45000 rows to census2021-ts075-oa
# Copied 50000 rows to census2021-ts075-oa
# Copied 55000 rows to census2021-ts075-oa
# Copied 60000 rows to census2021-ts075-oa
# Copied 65000 rows to census2021-ts075-oa
# Copied 70000 rows to census2021-ts075-oa
# Copied 75000 rows to census2021-ts075-oa
# Copied 80000 rows to census2021-ts075-oa
# Copied 85000 rows to census2021-ts075-oa
# Copied 90000 rows to census2021-ts075-oa
# Copied 95000 rows to census2021-ts075-oa
# Copied 100000 rows to census2021-ts075-oa
# Copied 105000 rows to census2021-ts075-oa
# Copied 110000 rows to census2021-ts075-oa
# Copied 115000 rows to census2021-ts075-oa
# Copied 120000 rows to census2021-ts075-oa
# Copied 125000 rows to census2021-ts075-oa
# Copied 130000 rows to census2021-ts075-oa
# Copied 135000 rows to census2021-ts075-oa
# Copied 140000 rows to census2021-ts075-oa
# Copied 145000 rows to census2021-ts075-oa
# Copied 150000 rows to census2021-ts075-oa
# Copied 155000 rows to census2021-ts075-oa
# Copied 160000 rows to census2021-ts075-oa
# Copied 165000 rows to census2021-ts075-oa
# Copied 170000 rows to census2021-ts075-oa
# Copied 175000 rows to census2021-ts075-oa
# Copied 180000 rows to census2021-ts075-oa
# Copied 185000 rows to census2021-ts075-oa
# Copied 188880 rows to census2021-ts075-oa
# Copying table: census2021-ts011-oa
# Copied 5000 rows to census2021-ts011-oa
# Copied 10000 rows to census2021-ts011-oa
# Copied 15000 rows to census2021-ts011-oa
# Copied 20000 rows to census2021-ts011-oa
# Copied 25000 rows to census2021-ts011-oa
# Copied 30000 rows to census2021-ts011-oa
# Copied 35000 rows to census2021-ts011-oa
# Copied 40000 rows to census2021-ts011-oa
# Copied 45000 rows to census2021-ts011-oa
# Copied 50000 rows to census2021-ts011-oa
# Copied 55000 rows to census2021-ts011-oa
# Copied 60000 rows to census2021-ts011-oa
# Copied 65000 rows to census2021-ts011-oa
# Copied 70000 rows to census2021-ts011-oa
# Copied 75000 rows to census2021-ts011-oa
# Copied 80000 rows to census2021-ts011-oa
# Copied 85000 rows to census2021-ts011-oa
# Copied 90000 rows to census2021-ts011-oa
# Copied 95000 rows to census2021-ts011-oa
# Copied 100000 rows to census2021-ts011-oa
# Copied 105000 rows to census2021-ts011-oa
# Copied 110000 rows to census2021-ts011-oa
# Copied 115000 rows to census2021-ts011-oa
# Copied 120000 rows to census2021-ts011-oa
# Copied 125000 rows to census2021-ts011-oa
# Copied 130000 rows to census2021-ts011-oa
# Copied 135000 rows to census2021-ts011-oa
# Copied 140000 rows to census2021-ts011-oa
# Copied 145000 rows to census2021-ts011-oa
# Copied 150000 rows to census2021-ts011-oa
# Copied 155000 rows to census2021-ts011-oa
# Copied 160000 rows to census2021-ts011-oa
# Copied 165000 rows to census2021-ts011-oa
# Copied 170000 rows to census2021-ts011-oa
# Copied 175000 rows to census2021-ts011-oa
# Copied 180000 rows to census2021-ts011-oa
# Copied 185000 rows to census2021-ts011-oa
# Copied 188880 rows to census2021-ts011-oa
# Copying table: census2021-ts011-utla
# Copied 174 rows to census2021-ts011-utla
# Copying table: census2021-ts011-lsoa
# Copied 5000 rows to census2021-ts011-lsoa
# Copied 10000 rows to census2021-ts011-lsoa
# Copied 15000 rows to census2021-ts011-lsoa
# Copied 20000 rows to census2021-ts011-lsoa
# Copied 25000 rows to census2021-ts011-lsoa
# Copied 30000 rows to census2021-ts011-lsoa
# Copied 35000 rows to census2021-ts011-lsoa
# Copied 35672 rows to census2021-ts011-lsoa
# Copying table: census2021-ts011-msoa
# Copied 5000 rows to census2021-ts011-msoa
# Copied 7264 rows to census2021-ts011-msoa
# Copying table: census2021-ts011-rgn
# Copied 10 rows to census2021-ts011-rgn
# Copying table: census2021-ts011-ltla
# Copied 331 rows to census2021-ts011-ltla
# Copying table: census2021-ts011-ctry
# Copied 3 rows to census2021-ts011-ctry
# Copying table: census2021-ts029-oa
# Copied 5000 rows to census2021-ts029-oa
# Copied 10000 rows to census2021-ts029-oa
# Copied 15000 rows to census2021-ts029-oa
# Copied 20000 rows to census2021-ts029-oa
# Copied 25000 rows to census2021-ts029-oa
# Copied 30000 rows to census2021-ts029-oa
# Copied 35000 rows to census2021-ts029-oa
# Copied 40000 rows to census2021-ts029-oa
# Copied 45000 rows to census2021-ts029-oa
# Copied 50000 rows to census2021-ts029-oa
# Copied 55000 rows to census2021-ts029-oa
# Copied 60000 rows to census2021-ts029-oa
# Copied 65000 rows to census2021-ts029-oa
# Copied 70000 rows to census2021-ts029-oa
# Copied 75000 rows to census2021-ts029-oa
# Copied 80000 rows to census2021-ts029-oa
# Copied 85000 rows to census2021-ts029-oa
# Copied 90000 rows to census2021-ts029-oa
# Copied 95000 rows to census2021-ts029-oa
# Copied 100000 rows to census2021-ts029-oa
# Copied 105000 rows to census2021-ts029-oa
# Copied 110000 rows to census2021-ts029-oa
# Copied 115000 rows to census2021-ts029-oa
# Copied 120000 rows to census2021-ts029-oa
# Copied 125000 rows to census2021-ts029-oa
# Copied 130000 rows to census2021-ts029-oa
# Copied 135000 rows to census2021-ts029-oa
# Copied 140000 rows to census2021-ts029-oa
# Copied 145000 rows to census2021-ts029-oa
# Copied 150000 rows to census2021-ts029-oa
# Copied 155000 rows to census2021-ts029-oa
# Copied 160000 rows to census2021-ts029-oa
# Copied 165000 rows to census2021-ts029-oa
# Copied 170000 rows to census2021-ts029-oa
# Copied 175000 rows to census2021-ts029-oa
# Copied 180000 rows to census2021-ts029-oa
# Copied 185000 rows to census2021-ts029-oa
# Copied 188880 rows to census2021-ts029-oa
# Copying table: census2021-ts029-utla
# Copied 174 rows to census2021-ts029-utla
# Copying table: census2021-ts029-lsoa
# Copied 5000 rows to census2021-ts029-lsoa
# Copied 10000 rows to census2021-ts029-lsoa
# Copied 15000 rows to census2021-ts029-lsoa
# Copied 20000 rows to census2021-ts029-lsoa
# Copied 25000 rows to census2021-ts029-lsoa
# Copied 30000 rows to census2021-ts029-lsoa
# Copied 35000 rows to census2021-ts029-lsoa
# Copied 35672 rows to census2021-ts029-lsoa
# Copying table: census2021-ts029-rgn
# Copied 10 rows to census2021-ts029-rgn
# Copying table: census2021-ts029-ctry
# Copied 3 rows to census2021-ts029-ctry
# Copying table: census2021-ts029-msoa
# Copied 5000 rows to census2021-ts029-msoa
# Copied 7264 rows to census2021-ts029-msoa
# Copying table: census2021-ts029-ltla
# Copied 331 rows to census2021-ts029-ltla
# Copying table: census2021-ts016-lsoa
# Copied 5000 rows to census2021-ts016-lsoa
# Copied 10000 rows to census2021-ts016-lsoa
# Copied 15000 rows to census2021-ts016-lsoa
# Copied 20000 rows to census2021-ts016-lsoa
# Copied 25000 rows to census2021-ts016-lsoa
# Copied 30000 rows to census2021-ts016-lsoa
# Copied 35000 rows to census2021-ts016-lsoa
# Copied 35672 rows to census2021-ts016-lsoa
# Copying table: census2021-ts016-ulta
# Copied 174 rows to census2021-ts016-ulta
# Copying table: census2021-ts016-rgn
# Copied 10 rows to census2021-ts016-rgn
# Copying table: census2021-ts016-ctry
# Copied 3 rows to census2021-ts016-ctry
# Copying table: census2021-ts016-msoa
# Copied 5000 rows to census2021-ts016-msoa
# Copied 7264 rows to census2021-ts016-msoa
# Copying table: census2021-ts016-ltla
# Copied 331 rows to census2021-ts016-ltla
# Copying table: census2021-ts016-oa
# Copied 5000 rows to census2021-ts016-oa
# Copied 10000 rows to census2021-ts016-oa
# Copied 15000 rows to census2021-ts016-oa
# Copied 20000 rows to census2021-ts016-oa
# Copied 25000 rows to census2021-ts016-oa
# Copied 30000 rows to census2021-ts016-oa
# Copied 35000 rows to census2021-ts016-oa
# Copied 40000 rows to census2021-ts016-oa
# Copied 45000 rows to census2021-ts016-oa
# Copied 50000 rows to census2021-ts016-oa
# Copied 55000 rows to census2021-ts016-oa
# Copied 60000 rows to census2021-ts016-oa
# Copied 65000 rows to census2021-ts016-oa
# Copied 70000 rows to census2021-ts016-oa
# Copied 75000 rows to census2021-ts016-oa
# Copied 80000 rows to census2021-ts016-oa
# Copied 85000 rows to census2021-ts016-oa
# Copied 90000 rows to census2021-ts016-oa
# Copied 95000 rows to census2021-ts016-oa
# Copied 100000 rows to census2021-ts016-oa
# Copied 105000 rows to census2021-ts016-oa
# Copied 110000 rows to census2021-ts016-oa
# Copied 115000 rows to census2021-ts016-oa
# Copied 120000 rows to census2021-ts016-oa
# Copied 125000 rows to census2021-ts016-oa
# Copied 130000 rows to census2021-ts016-oa
# Copied 135000 rows to census2021-ts016-oa
# Copied 140000 rows to census2021-ts016-oa
# Copied 145000 rows to census2021-ts016-oa
# Copied 150000 rows to census2021-ts016-oa
# Copied 155000 rows to census2021-ts016-oa
# Copied 160000 rows to census2021-ts016-oa
# Copied 165000 rows to census2021-ts016-oa
# Copied 170000 rows to census2021-ts016-oa
# Copied 175000 rows to census2021-ts016-oa
# Copied 180000 rows to census2021-ts016-oa
# Copied 185000 rows to census2021-ts016-oa
# Copied 188880 rows to census2021-ts016-oa
# Copying table: census2021-ts020-msoa
# Copied 5000 rows to census2021-ts020-msoa
# Copied 7264 rows to census2021-ts020-msoa
# Copying table: census2021-ts020-ltla
# Copied 331 rows to census2021-ts020-ltla
# Copying table: census2021-ts020-ctry
# Copied 3 rows to census2021-ts020-ctry
# Copying table: census2021-ts020-rgn
# Copied 10 rows to census2021-ts020-rgn
# Copying table: census2021-ts020-utla
# Copied 174 rows to census2021-ts020-utla
# Copying table: census2021-ts020-lsoa
# Copied 5000 rows to census2021-ts020-lsoa
# Copied 10000 rows to census2021-ts020-lsoa
# Copied 15000 rows to census2021-ts020-lsoa
# Copied 20000 rows to census2021-ts020-lsoa
# Copied 25000 rows to census2021-ts020-lsoa
# Copied 30000 rows to census2021-ts020-lsoa
# Copied 35000 rows to census2021-ts020-lsoa
# Copied 35672 rows to census2021-ts020-lsoa
# Copying table: census2021-ts020-oa
# Copied 5000 rows to census2021-ts020-oa
# Copied 10000 rows to census2021-ts020-oa
# Copied 15000 rows to census2021-ts020-oa
# Copied 20000 rows to census2021-ts020-oa
# Copied 25000 rows to census2021-ts020-oa
# Copied 30000 rows to census2021-ts020-oa
# Copied 35000 rows to census2021-ts020-oa
# Copied 40000 rows to census2021-ts020-oa
# Copied 45000 rows to census2021-ts020-oa
# Copied 50000 rows to census2021-ts020-oa
# Copied 55000 rows to census2021-ts020-oa
# Copied 60000 rows to census2021-ts020-oa
# Copied 65000 rows to census2021-ts020-oa
# Copied 70000 rows to census2021-ts020-oa
# Copied 75000 rows to census2021-ts020-oa
# Copied 80000 rows to census2021-ts020-oa
# Copied 85000 rows to census2021-ts020-oa
# Copied 90000 rows to census2021-ts020-oa
# Copied 95000 rows to census2021-ts020-oa
# Copied 100000 rows to census2021-ts020-oa
# Copied 105000 rows to census2021-ts020-oa
# Copied 110000 rows to census2021-ts020-oa
# Copied 115000 rows to census2021-ts020-oa
# Copied 120000 rows to census2021-ts020-oa
# Copied 125000 rows to census2021-ts020-oa
# Copied 130000 rows to census2021-ts020-oa
# Copied 135000 rows to census2021-ts020-oa
# Copied 140000 rows to census2021-ts020-oa
# Copied 145000 rows to census2021-ts020-oa
# Copied 150000 rows to census2021-ts020-oa
# Copied 155000 rows to census2021-ts020-oa
# Copied 160000 rows to census2021-ts020-oa
# Copied 165000 rows to census2021-ts020-oa
# Copied 170000 rows to census2021-ts020-oa
# Copied 175000 rows to census2021-ts020-oa
# Copied 180000 rows to census2021-ts020-oa
# Copied 185000 rows to census2021-ts020-oa
# Copied 188880 rows to census2021-ts020-oa
# Copying table: census2021-ts018-ctry
# Copied 3 rows to census2021-ts018-ctry
# Copying table: census2021-ts018-msoa
# Copied 5000 rows to census2021-ts018-msoa
# Copied 7264 rows to census2021-ts018-msoa
# Copying table: census2021-ts018-ltla
# Copied 331 rows to census2021-ts018-ltla
# Copying table: census2021-ts018-ulta
# Copied 174 rows to census2021-ts018-ulta
# Copying table: census2021-ts018-rgn
# Copied 10 rows to census2021-ts018-rgn
# Copying table: census2021-ts018-oa
# Copied 5000 rows to census2021-ts018-oa
# Copied 10000 rows to census2021-ts018-oa
# Copied 15000 rows to census2021-ts018-oa
# Copied 20000 rows to census2021-ts018-oa
# Copied 25000 rows to census2021-ts018-oa
# Copied 30000 rows to census2021-ts018-oa
# Copied 35000 rows to census2021-ts018-oa
# Copied 40000 rows to census2021-ts018-oa
# Copied 45000 rows to census2021-ts018-oa
# Copied 50000 rows to census2021-ts018-oa
# Copied 55000 rows to census2021-ts018-oa
# Copied 60000 rows to census2021-ts018-oa
# Copied 65000 rows to census2021-ts018-oa
# Copied 70000 rows to census2021-ts018-oa
# Copied 75000 rows to census2021-ts018-oa
# Copied 80000 rows to census2021-ts018-oa
# Copied 85000 rows to census2021-ts018-oa
# Copied 90000 rows to census2021-ts018-oa
# Copied 95000 rows to census2021-ts018-oa
# Copied 100000 rows to census2021-ts018-oa
# Copied 105000 rows to census2021-ts018-oa
# Copied 110000 rows to census2021-ts018-oa
# Copied 115000 rows to census2021-ts018-oa
# Copied 120000 rows to census2021-ts018-oa
# Copied 125000 rows to census2021-ts018-oa
# Copied 130000 rows to census2021-ts018-oa
# Copied 135000 rows to census2021-ts018-oa
# Copied 140000 rows to census2021-ts018-oa
# Copied 145000 rows to census2021-ts018-oa
# Copied 150000 rows to census2021-ts018-oa
# Copied 155000 rows to census2021-ts018-oa
# Copied 160000 rows to census2021-ts018-oa
# Copied 165000 rows to census2021-ts018-oa
# Copied 170000 rows to census2021-ts018-oa
# Copied 175000 rows to census2021-ts018-oa
# Copied 180000 rows to census2021-ts018-oa
# Copied 185000 rows to census2021-ts018-oa
# Copied 188880 rows to census2021-ts018-oa
# Copying table: census2021-ts018-lsoa
# Copied 5000 rows to census2021-ts018-lsoa
# Copied 10000 rows to census2021-ts018-lsoa
# Copied 15000 rows to census2021-ts018-lsoa
# Copied 20000 rows to census2021-ts018-lsoa
# Copied 25000 rows to census2021-ts018-lsoa
# Copied 30000 rows to census2021-ts018-lsoa
# Copied 35000 rows to census2021-ts018-lsoa
# Copied 35672 rows to census2021-ts018-lsoa
# Copying table: census2021-ts027-oa
# Copied 5000 rows to census2021-ts027-oa
# Copied 10000 rows to census2021-ts027-oa
# Copied 15000 rows to census2021-ts027-oa
# Copied 20000 rows to census2021-ts027-oa
# Copied 25000 rows to census2021-ts027-oa
# Copied 30000 rows to census2021-ts027-oa
# Copied 35000 rows to census2021-ts027-oa
# Copied 40000 rows to census2021-ts027-oa
# Copied 45000 rows to census2021-ts027-oa
# Copied 50000 rows to census2021-ts027-oa
# Copied 55000 rows to census2021-ts027-oa
# Copied 60000 rows to census2021-ts027-oa
# Copied 65000 rows to census2021-ts027-oa
# Copied 70000 rows to census2021-ts027-oa
# Copied 75000 rows to census2021-ts027-oa
# Copied 80000 rows to census2021-ts027-oa
# Copied 85000 rows to census2021-ts027-oa
# Copied 90000 rows to census2021-ts027-oa
# Copied 95000 rows to census2021-ts027-oa
# Copied 100000 rows to census2021-ts027-oa
# Copied 105000 rows to census2021-ts027-oa
# Copied 110000 rows to census2021-ts027-oa
# Copied 115000 rows to census2021-ts027-oa
# Copied 120000 rows to census2021-ts027-oa
# Copied 125000 rows to census2021-ts027-oa
# Copied 130000 rows to census2021-ts027-oa
# Copied 135000 rows to census2021-ts027-oa
# Copied 140000 rows to census2021-ts027-oa
# Copied 145000 rows to census2021-ts027-oa
# Copied 150000 rows to census2021-ts027-oa
# Copied 155000 rows to census2021-ts027-oa
# Copied 160000 rows to census2021-ts027-oa
# Copied 165000 rows to census2021-ts027-oa
# Copied 170000 rows to census2021-ts027-oa
# Copied 175000 rows to census2021-ts027-oa
# Copied 180000 rows to census2021-ts027-oa
# Copied 185000 rows to census2021-ts027-oa
# Copied 188880 rows to census2021-ts027-oa
# Copying table: census2021-ts027-ctry
# Copied 3 rows to census2021-ts027-ctry
# Copying table: census2021-ts027-msoa
# Copied 5000 rows to census2021-ts027-msoa
# Copied 7264 rows to census2021-ts027-msoa
# Copying table: census2021-ts027-ltla
# Copied 331 rows to census2021-ts027-ltla
# Copying table: census2021-ts027-rgn
# Copied 10 rows to census2021-ts027-rgn
# Copying table: census2021-ts027-utla
# Copied 174 rows to census2021-ts027-utla
# Copying table: census2021-ts027-lsoa
# Copied 5000 rows to census2021-ts027-lsoa
# Copied 10000 rows to census2021-ts027-lsoa
# Copied 15000 rows to census2021-ts027-lsoa
# Copied 20000 rows to census2021-ts027-lsoa
# Copied 25000 rows to census2021-ts027-lsoa
# Copied 30000 rows to census2021-ts027-lsoa
# Copied 35000 rows to census2021-ts027-lsoa
# Copied 35672 rows to census2021-ts027-lsoa
# Copying table: census2021-ts007a-oa
# Copied 5000 rows to census2021-ts007a-oa
# Copied 10000 rows to census2021-ts007a-oa
# Copied 15000 rows to census2021-ts007a-oa
# Copied 20000 rows to census2021-ts007a-oa
# Copied 25000 rows to census2021-ts007a-oa
# Copied 30000 rows to census2021-ts007a-oa
# Copied 35000 rows to census2021-ts007a-oa
# Copied 40000 rows to census2021-ts007a-oa
# Copied 45000 rows to census2021-ts007a-oa
# Copied 50000 rows to census2021-ts007a-oa
# Copied 55000 rows to census2021-ts007a-oa
# Copied 60000 rows to census2021-ts007a-oa
# Copied 65000 rows to census2021-ts007a-oa
# Copied 70000 rows to census2021-ts007a-oa
# Copied 75000 rows to census2021-ts007a-oa
# Copied 80000 rows to census2021-ts007a-oa
# Copied 85000 rows to census2021-ts007a-oa
# Copied 90000 rows to census2021-ts007a-oa
# Copied 95000 rows to census2021-ts007a-oa
# Copied 100000 rows to census2021-ts007a-oa
# Copied 105000 rows to census2021-ts007a-oa
# Copied 110000 rows to census2021-ts007a-oa
# Copied 115000 rows to census2021-ts007a-oa
# Copied 120000 rows to census2021-ts007a-oa
# Copied 125000 rows to census2021-ts007a-oa
# Copied 130000 rows to census2021-ts007a-oa
# Copied 135000 rows to census2021-ts007a-oa
# Copied 140000 rows to census2021-ts007a-oa
# Copied 145000 rows to census2021-ts007a-oa
# Copied 150000 rows to census2021-ts007a-oa
# Copied 155000 rows to census2021-ts007a-oa
# Copied 160000 rows to census2021-ts007a-oa
# Copied 165000 rows to census2021-ts007a-oa
# Copied 170000 rows to census2021-ts007a-oa
# Copied 175000 rows to census2021-ts007a-oa
# Copied 180000 rows to census2021-ts007a-oa
# Copied 185000 rows to census2021-ts007a-oa
# Copied 188880 rows to census2021-ts007a-oa
# Copying table: census2021-ts007a-ctry
# Copied 3 rows to census2021-ts007a-ctry
# Copying table: census2021-ts007a-ltla
# Copied 331 rows to census2021-ts007a-ltla
# Copying table: census2021-ts007a-msoa
# Copied 5000 rows to census2021-ts007a-msoa
# Copied 7264 rows to census2021-ts007a-msoa
# Copying table: census2021-ts007a-rgn
# Copied 10 rows to census2021-ts007a-rgn
# Copying table: census2021-ts007a-lsoa
# Copied 5000 rows to census2021-ts007a-lsoa
# Copied 10000 rows to census2021-ts007a-lsoa
# Copied 15000 rows to census2021-ts007a-lsoa
# Copied 20000 rows to census2021-ts007a-lsoa
# Copied 25000 rows to census2021-ts007a-lsoa
# Copied 30000 rows to census2021-ts007a-lsoa
# Copied 35000 rows to census2021-ts007a-lsoa
# Copied 35672 rows to census2021-ts007a-lsoa
# Copying table: census2021-ts007a-utla
# Copied 174 rows to census2021-ts007a-utla
# Copying table: census2021-ts006-ulta
# Copied 174 rows to census2021-ts006-ulta
# Copying table: census2021-ts006-rgn
# Copied 10 rows to census2021-ts006-rgn
# Copying table: census2021-ts006-lsoa
# Copied 5000 rows to census2021-ts006-lsoa
# Copied 10000 rows to census2021-ts006-lsoa
# Copied 15000 rows to census2021-ts006-lsoa
# Copied 20000 rows to census2021-ts006-lsoa
# Copied 25000 rows to census2021-ts006-lsoa
# Copied 30000 rows to census2021-ts006-lsoa
# Copied 35000 rows to census2021-ts006-lsoa
# Copied 35672 rows to census2021-ts006-lsoa
# Copying table: census2021-ts006-ctry
# Copied 3 rows to census2021-ts006-ctry
# Copying table: census2021-ts006-oa
# Copied 5000 rows to census2021-ts006-oa
# Copied 10000 rows to census2021-ts006-oa
# Copied 15000 rows to census2021-ts006-oa
# Copied 20000 rows to census2021-ts006-oa
# Copied 25000 rows to census2021-ts006-oa
# Copied 30000 rows to census2021-ts006-oa
# Copied 35000 rows to census2021-ts006-oa
# Copied 40000 rows to census2021-ts006-oa
# Copied 45000 rows to census2021-ts006-oa
# Copied 50000 rows to census2021-ts006-oa
# Copied 55000 rows to census2021-ts006-oa
# Copied 60000 rows to census2021-ts006-oa
# Copied 65000 rows to census2021-ts006-oa
# Copied 70000 rows to census2021-ts006-oa
# Copied 75000 rows to census2021-ts006-oa
# Copied 80000 rows to census2021-ts006-oa
# Copied 85000 rows to census2021-ts006-oa
# Copied 90000 rows to census2021-ts006-oa
# Copied 95000 rows to census2021-ts006-oa
# Copied 100000 rows to census2021-ts006-oa
# Copied 105000 rows to census2021-ts006-oa
# Copied 110000 rows to census2021-ts006-oa
# Copied 115000 rows to census2021-ts006-oa
# Copied 120000 rows to census2021-ts006-oa
# Copied 125000 rows to census2021-ts006-oa
# Copied 130000 rows to census2021-ts006-oa
# Copied 135000 rows to census2021-ts006-oa
# Copied 140000 rows to census2021-ts006-oa
# Copied 145000 rows to census2021-ts006-oa
# Copied 150000 rows to census2021-ts006-oa
# Copied 155000 rows to census2021-ts006-oa
# Copied 160000 rows to census2021-ts006-oa
# Copied 165000 rows to census2021-ts006-oa
# Copied 170000 rows to census2021-ts006-oa
# Copied 175000 rows to census2021-ts006-oa
# Copied 180000 rows to census2021-ts006-oa
# Copied 185000 rows to census2021-ts006-oa
# Copied 188880 rows to census2021-ts006-oa
# Copying table: census2021-ts006-msoa
# Copied 5000 rows to census2021-ts006-msoa
# Copied 7264 rows to census2021-ts006-msoa
# Copying table: census2021-ts006-ltla
# Copied 331 rows to census2021-ts006-ltla
# Copying table: census2021-ts030-msoa
# Copied 5000 rows to census2021-ts030-msoa
# Copied 7264 rows to census2021-ts030-msoa
# Copying table: census2021-ts030-rgn
# Copied 10 rows to census2021-ts030-rgn
# Copying table: census2021-ts030-ltla
# Copied 331 rows to census2021-ts030-ltla
# Copying table: census2021-ts030-ctry
# Copied 3 rows to census2021-ts030-ctry
# Copying table: census2021-ts030-utla
# Copied 174 rows to census2021-ts030-utla
# Copying table: census2021-ts030-lsoa
# Copied 5000 rows to census2021-ts030-lsoa
# Copied 10000 rows to census2021-ts030-lsoa
# Copied 15000 rows to census2021-ts030-lsoa
# Copied 20000 rows to census2021-ts030-lsoa
# Copied 25000 rows to census2021-ts030-lsoa
# Copied 30000 rows to census2021-ts030-lsoa
# Copied 35000 rows to census2021-ts030-lsoa
# Copied 35672 rows to census2021-ts030-lsoa
# Copying table: census2021-ts030-oa
# Copied 5000 rows to census2021-ts030-oa
# Copied 10000 rows to census2021-ts030-oa
# Copied 15000 rows to census2021-ts030-oa
# Copied 20000 rows to census2021-ts030-oa
# Copied 25000 rows to census2021-ts030-oa
# Copied 30000 rows to census2021-ts030-oa
# Copied 35000 rows to census2021-ts030-oa
# Copied 40000 rows to census2021-ts030-oa
# Copied 45000 rows to census2021-ts030-oa
# Copied 50000 rows to census2021-ts030-oa
# Copied 55000 rows to census2021-ts030-oa
# Copied 60000 rows to census2021-ts030-oa
# Copied 65000 rows to census2021-ts030-oa
# Copied 70000 rows to census2021-ts030-oa
# Copied 75000 rows to census2021-ts030-oa
# Copied 80000 rows to census2021-ts030-oa
# Copied 85000 rows to census2021-ts030-oa
# Copied 90000 rows to census2021-ts030-oa
# Copied 95000 rows to census2021-ts030-oa
# Copied 100000 rows to census2021-ts030-oa
# Copied 105000 rows to census2021-ts030-oa
# Copied 110000 rows to census2021-ts030-oa
# Copied 115000 rows to census2021-ts030-oa
# Copied 120000 rows to census2021-ts030-oa
# Copied 125000 rows to census2021-ts030-oa
# Copied 130000 rows to census2021-ts030-oa
# Copied 135000 rows to census2021-ts030-oa
# Copied 140000 rows to census2021-ts030-oa
# Copied 145000 rows to census2021-ts030-oa
# Copied 150000 rows to census2021-ts030-oa
# Copied 155000 rows to census2021-ts030-oa
# Copied 160000 rows to census2021-ts030-oa
# Copied 165000 rows to census2021-ts030-oa
# Copied 170000 rows to census2021-ts030-oa
# Copied 175000 rows to census2021-ts030-oa
# Copied 180000 rows to census2021-ts030-oa
# Copied 185000 rows to census2021-ts030-oa
# Copied 188880 rows to census2021-ts030-oa
# Copying table: census2021-ts008-ctry
# Copied 3 rows to census2021-ts008-ctry
# Copying table: census2021-ts008-msoa
# Copied 5000 rows to census2021-ts008-msoa
# Copied 7264 rows to census2021-ts008-msoa
# Copying table: census2021-ts008-ltla
# Copied 331 rows to census2021-ts008-ltla
# Copying table: census2021-ts008-lsoa
# Copied 5000 rows to census2021-ts008-lsoa
# Copied 10000 rows to census2021-ts008-lsoa
# Copied 15000 rows to census2021-ts008-lsoa
# Copied 20000 rows to census2021-ts008-lsoa
# Copied 25000 rows to census2021-ts008-lsoa
# Copied 30000 rows to census2021-ts008-lsoa
# Copied 35000 rows to census2021-ts008-lsoa
# Copied 35672 rows to census2021-ts008-lsoa
# Copying table: census2021-ts008-ulta
# Copied 174 rows to census2021-ts008-ulta
# Copying table: census2021-ts008-oa
# Copied 5000 rows to census2021-ts008-oa
# Copied 10000 rows to census2021-ts008-oa
# Copied 15000 rows to census2021-ts008-oa
# Copied 20000 rows to census2021-ts008-oa
# Copied 25000 rows to census2021-ts008-oa
# Copied 30000 rows to census2021-ts008-oa
# Copied 35000 rows to census2021-ts008-oa
# Copied 40000 rows to census2021-ts008-oa
# Copied 45000 rows to census2021-ts008-oa
# Copied 50000 rows to census2021-ts008-oa
# Copied 55000 rows to census2021-ts008-oa
# Copied 60000 rows to census2021-ts008-oa
# Copied 65000 rows to census2021-ts008-oa
# Copied 70000 rows to census2021-ts008-oa
# Copied 75000 rows to census2021-ts008-oa
# Copied 80000 rows to census2021-ts008-oa
# Copied 85000 rows to census2021-ts008-oa
# Copied 90000 rows to census2021-ts008-oa
# Copied 95000 rows to census2021-ts008-oa
# Copied 100000 rows to census2021-ts008-oa
# Copied 105000 rows to census2021-ts008-oa
# Copied 110000 rows to census2021-ts008-oa
# Copied 115000 rows to census2021-ts008-oa
# Copied 120000 rows to census2021-ts008-oa
# Copied 125000 rows to census2021-ts008-oa
# Copied 130000 rows to census2021-ts008-oa
# Copied 135000 rows to census2021-ts008-oa
# Copied 140000 rows to census2021-ts008-oa
# Copied 145000 rows to census2021-ts008-oa
# Copied 150000 rows to census2021-ts008-oa
# Copied 155000 rows to census2021-ts008-oa
# Copied 160000 rows to census2021-ts008-oa
# Copied 165000 rows to census2021-ts008-oa
# Copied 170000 rows to census2021-ts008-oa
# Copied 175000 rows to census2021-ts008-oa
# Copied 180000 rows to census2021-ts008-oa
# Copied 185000 rows to census2021-ts008-oa
# Copied 188880 rows to census2021-ts008-oa
# Copying table: census2021-ts008-rgn
# Copied 10 rows to census2021-ts008-rgn
# Copying table: census2021-ts009-ctry
# Copied 3 rows to census2021-ts009-ctry
# Copying table: census2021-ts009-ltla
# Copied 331 rows to census2021-ts009-ltla
# Copying table: census2021-ts009-ulta
# Copied 174 rows to census2021-ts009-ulta
# Copying table: census2021-ts009-rgn
# Copied 10 rows to census2021-ts009-rgn
# Copying table: census2021-ts031-msoa
# Copied 5000 rows to census2021-ts031-msoa
# Copied 7264 rows to census2021-ts031-msoa
# Copying table: census2021-ts031-ltla
# Copied 331 rows to census2021-ts031-ltla
# Copying table: census2021-ts031-ctry
# Copied 3 rows to census2021-ts031-ctry
# Copying table: census2021-ts031-rgn
# Copied 10 rows to census2021-ts031-rgn
# Copying table: census2021-ts031-utla
# Copied 174 rows to census2021-ts031-utla
# Copying table: census2021-ts007-rgn
# Copied 10 rows to census2021-ts007-rgn
# Copying table: census2021-ts007-utla
# Copied 174 rows to census2021-ts007-utla
# Copying table: census2021-ts007-ctry
# Copied 3 rows to census2021-ts007-ctry
# Copying table: census2021-ts007-msoa
# Copied 5000 rows to census2021-ts007-msoa
# Copied 7264 rows to census2021-ts007-msoa
# Copying table: census2021-ts007-ltla
# Copied 331 rows to census2021-ts007-ltla
# Copying table: census2021-ts022-rgn
# Copied 10 rows to census2021-ts022-rgn
# Copying table: census2021-ts022-utla
# Copied 174 rows to census2021-ts022-utla
# Copying table: census2021-ts022-ctry
# Copied 3 rows to census2021-ts022-ctry
# Copying table: census2021-ts022-ltla
# Copied 331 rows to census2021-ts022-ltla
# Copying table: census2021-ts022-msoa
# Copied 5000 rows to census2021-ts022-msoa
# Copied 7264 rows to census2021-ts022-msoa
# Copying table: census2021-ts025-oa
# Copied 5000 rows to census2021-ts025-oa
# Copied 10000 rows to census2021-ts025-oa
# Copied 15000 rows to census2021-ts025-oa
# Copied 20000 rows to census2021-ts025-oa
# Copied 25000 rows to census2021-ts025-oa
# Copied 30000 rows to census2021-ts025-oa
# Copied 35000 rows to census2021-ts025-oa
# Copied 40000 rows to census2021-ts025-oa
# Copied 45000 rows to census2021-ts025-oa
# Copied 50000 rows to census2021-ts025-oa
# Copied 55000 rows to census2021-ts025-oa
# Copied 60000 rows to census2021-ts025-oa
# Copied 65000 rows to census2021-ts025-oa
# Copied 70000 rows to census2021-ts025-oa
# Copied 75000 rows to census2021-ts025-oa
# Copied 80000 rows to census2021-ts025-oa
# Copied 85000 rows to census2021-ts025-oa
# Copied 90000 rows to census2021-ts025-oa
# Copied 95000 rows to census2021-ts025-oa
# Copied 100000 rows to census2021-ts025-oa
# Copied 105000 rows to census2021-ts025-oa
# Copied 110000 rows to census2021-ts025-oa
# Copied 115000 rows to census2021-ts025-oa
# Copied 120000 rows to census2021-ts025-oa
# Copied 125000 rows to census2021-ts025-oa
# Copied 130000 rows to census2021-ts025-oa
# Copied 135000 rows to census2021-ts025-oa
# Copied 140000 rows to census2021-ts025-oa
# Copied 145000 rows to census2021-ts025-oa
# Copied 150000 rows to census2021-ts025-oa
# Copied 155000 rows to census2021-ts025-oa
# Copied 160000 rows to census2021-ts025-oa
# Copied 165000 rows to census2021-ts025-oa
# Copied 170000 rows to census2021-ts025-oa
# Copied 175000 rows to census2021-ts025-oa
# Copied 180000 rows to census2021-ts025-oa
# Copied 185000 rows to census2021-ts025-oa
# Copied 188880 rows to census2021-ts025-oa
# Copying table: census2021-ts025-lsoa
# Copied 5000 rows to census2021-ts025-lsoa
# Copied 10000 rows to census2021-ts025-lsoa
# Copied 15000 rows to census2021-ts025-lsoa
# Copied 20000 rows to census2021-ts025-lsoa
# Copied 25000 rows to census2021-ts025-lsoa
# Copied 30000 rows to census2021-ts025-lsoa
# Copied 35000 rows to census2021-ts025-lsoa
# Copied 35672 rows to census2021-ts025-lsoa
# Copying table: census2021-ts025-utla
# Copied 174 rows to census2021-ts025-utla
# Copying table: census2021-ts025-rgn
# Copied 10 rows to census2021-ts025-rgn
# Copying table: census2021-ts025-ltla
# Copied 331 rows to census2021-ts025-ltla
# Copying table: census2021-ts025-msoa
# Copied 5000 rows to census2021-ts025-msoa
# Copied 7264 rows to census2021-ts025-msoa
# Copying table: census2021-ts025-ctry
# Copied 3 rows to census2021-ts025-ctry
# Copying table: census2021-ts013-ctry
# Copied 3 rows to census2021-ts013-ctry
# Copying table: census2021-ts013-ltla
# Copied 331 rows to census2021-ts013-ltla
# Copying table: census2021-ts013-msoa
# Copied 5000 rows to census2021-ts013-msoa
# Copied 7264 rows to census2021-ts013-msoa
# Copying table: census2021-ts013-rgn
# Copied 10 rows to census2021-ts013-rgn
# Copying table: census2021-ts013-utla
# Copied 174 rows to census2021-ts013-utla
# Copying table: census2021-ts041-ctry
# Copied 3 rows to census2021-ts041-ctry
# Copying table: census2021-ts041-rgn
# Copied 10 rows to census2021-ts041-rgn
# Copying table: census2021-ts041-msoa
# Copied 5000 rows to census2021-ts041-msoa
# Copied 7264 rows to census2021-ts041-msoa
# Copying table: census2021-ts041-ltla
# Copied 331 rows to census2021-ts041-ltla
# Copying table: census2021-ts041-utla
# Copied 174 rows to census2021-ts041-utla
# Copying table: census2021-ts041-lsoa
# Copied 5000 rows to census2021-ts041-lsoa
# Copied 10000 rows to census2021-ts041-lsoa
# Copied 15000 rows to census2021-ts041-lsoa
# Copied 20000 rows to census2021-ts041-lsoa
# Copied 25000 rows to census2021-ts041-lsoa
# Copied 30000 rows to census2021-ts041-lsoa
# Copied 35000 rows to census2021-ts041-lsoa
# Copied 35672 rows to census2021-ts041-lsoa
# Copying table: census2021-ts041-oa
# Copied 5000 rows to census2021-ts041-oa
# Copied 10000 rows to census2021-ts041-oa
# Copied 15000 rows to census2021-ts041-oa
# Copied 20000 rows to census2021-ts041-oa
# Copied 25000 rows to census2021-ts041-oa
# Copied 30000 rows to census2021-ts041-oa
# Copied 35000 rows to census2021-ts041-oa
# Copied 40000 rows to census2021-ts041-oa
# Copied 45000 rows to census2021-ts041-oa
# Copied 50000 rows to census2021-ts041-oa
# Copied 55000 rows to census2021-ts041-oa
# Copied 60000 rows to census2021-ts041-oa
# Copied 65000 rows to census2021-ts041-oa
# Copied 70000 rows to census2021-ts041-oa
# Copied 75000 rows to census2021-ts041-oa
# Copied 80000 rows to census2021-ts041-oa
# Copied 85000 rows to census2021-ts041-oa
# Copied 90000 rows to census2021-ts041-oa
# Copied 95000 rows to census2021-ts041-oa
# Copied 100000 rows to census2021-ts041-oa
# Copied 105000 rows to census2021-ts041-oa
# Copied 110000 rows to census2021-ts041-oa
# Copied 115000 rows to census2021-ts041-oa
# Copied 120000 rows to census2021-ts041-oa
# Copied 125000 rows to census2021-ts041-oa
# Copied 130000 rows to census2021-ts041-oa
# Copied 135000 rows to census2021-ts041-oa
# Copied 140000 rows to census2021-ts041-oa
# Copied 145000 rows to census2021-ts041-oa
# Copied 150000 rows to census2021-ts041-oa
# Copied 155000 rows to census2021-ts041-oa
# Copied 160000 rows to census2021-ts041-oa
# Copied 165000 rows to census2021-ts041-oa
# Copied 170000 rows to census2021-ts041-oa
# Copied 175000 rows to census2021-ts041-oa
# Copied 180000 rows to census2021-ts041-oa
# Copied 185000 rows to census2021-ts041-oa
# Copied 188880 rows to census2021-ts041-oa
# Copying table: census2021-ts015-ltla
# Copied 331 rows to census2021-ts015-ltla
# Copying table: census2021-ts015-rgn
# Copied 10 rows to census2021-ts015-rgn
# Copying table: census2021-ts015-msoa
# Copied 5000 rows to census2021-ts015-msoa
# Copied 7264 rows to census2021-ts015-msoa
# Copying table: census2021-ts015-ctry
# Copied 3 rows to census2021-ts015-ctry
# Copying table: census2021-ts015-oa
# Copied 5000 rows to census2021-ts015-oa
# Copied 10000 rows to census2021-ts015-oa
# Copied 15000 rows to census2021-ts015-oa
# Copied 20000 rows to census2021-ts015-oa
# Copied 25000 rows to census2021-ts015-oa
# Copied 30000 rows to census2021-ts015-oa
# Copied 35000 rows to census2021-ts015-oa
# Copied 40000 rows to census2021-ts015-oa
# Copied 45000 rows to census2021-ts015-oa
# Copied 50000 rows to census2021-ts015-oa
# Copied 55000 rows to census2021-ts015-oa
# Copied 60000 rows to census2021-ts015-oa
# Copied 65000 rows to census2021-ts015-oa
# Copied 70000 rows to census2021-ts015-oa
# Copied 75000 rows to census2021-ts015-oa
# Copied 80000 rows to census2021-ts015-oa
# Copied 85000 rows to census2021-ts015-oa
# Copied 90000 rows to census2021-ts015-oa
# Copied 95000 rows to census2021-ts015-oa
# Copied 100000 rows to census2021-ts015-oa
# Copied 105000 rows to census2021-ts015-oa
# Copied 110000 rows to census2021-ts015-oa
# Copied 115000 rows to census2021-ts015-oa
# Copied 120000 rows to census2021-ts015-oa
# Copied 125000 rows to census2021-ts015-oa
# Copied 130000 rows to census2021-ts015-oa
# Copied 135000 rows to census2021-ts015-oa
# Copied 140000 rows to census2021-ts015-oa
# Copied 145000 rows to census2021-ts015-oa
# Copied 150000 rows to census2021-ts015-oa
# Copied 155000 rows to census2021-ts015-oa
# Copied 160000 rows to census2021-ts015-oa
# Copied 165000 rows to census2021-ts015-oa
# Copied 170000 rows to census2021-ts015-oa
# Copied 175000 rows to census2021-ts015-oa
# Copied 180000 rows to census2021-ts015-oa
# Copied 185000 rows to census2021-ts015-oa
# Copied 188880 rows to census2021-ts015-oa
# Copying table: census2021-ts015-lsoa
# Copied 5000 rows to census2021-ts015-lsoa
# Copied 10000 rows to census2021-ts015-lsoa
# Copied 15000 rows to census2021-ts015-lsoa
# Copied 20000 rows to census2021-ts015-lsoa
# Copied 25000 rows to census2021-ts015-lsoa
# Copied 30000 rows to census2021-ts015-lsoa
# Copied 35000 rows to census2021-ts015-lsoa
# Copied 35672 rows to census2021-ts015-lsoa
# Copying table: census2021-ts015-utla
# Copied 174 rows to census2021-ts015-utla
# Copying table: census2021-ts012-ctry
# Copied 3 rows to census2021-ts012-ctry
# Copying table: census2021-ts012-ltla
# Copied 331 rows to census2021-ts012-ltla
# Copying table: census2021-ts012-rgn
# Copied 10 rows to census2021-ts012-rgn
# Copying table: census2021-ts012-utla
# Copied 174 rows to census2021-ts012-utla
# Copying table: census2021-ts024-utla
# Copied 174 rows to census2021-ts024-utla
# Copying table: census2021-ts024-rgn
# Copied 10 rows to census2021-ts024-rgn
# Copying table: census2021-ts024-ltla
# Copied 331 rows to census2021-ts024-ltla
# Copying table: census2021-ts024-ctry
# Copied 3 rows to census2021-ts024-ctry
# Copying table: census2021-ts023-rgn
# Copied 10 rows to census2021-ts023-rgn
# Copying table: census2021-ts023-lsoa
# Copied 5000 rows to census2021-ts023-lsoa
# Copied 10000 rows to census2021-ts023-lsoa
# Copied 15000 rows to census2021-ts023-lsoa
# Copied 20000 rows to census2021-ts023-lsoa
# Copied 25000 rows to census2021-ts023-lsoa
# Copied 30000 rows to census2021-ts023-lsoa
# Copied 35000 rows to census2021-ts023-lsoa
# Copied 35672 rows to census2021-ts023-lsoa
# Copying table: census2021-ts023-utla
# Copied 174 rows to census2021-ts023-utla
# Copying table: census2021-ts023-oa
# Copied 5000 rows to census2021-ts023-oa
# Copied 10000 rows to census2021-ts023-oa
# Copied 15000 rows to census2021-ts023-oa
# Copied 20000 rows to census2021-ts023-oa
# Copied 25000 rows to census2021-ts023-oa
# Copied 30000 rows to census2021-ts023-oa
# Copied 35000 rows to census2021-ts023-oa
# Copied 40000 rows to census2021-ts023-oa
# Copied 45000 rows to census2021-ts023-oa
# Copied 50000 rows to census2021-ts023-oa
# Copied 55000 rows to census2021-ts023-oa
# Copied 60000 rows to census2021-ts023-oa
# Copied 65000 rows to census2021-ts023-oa
# Copied 70000 rows to census2021-ts023-oa
# Copied 75000 rows to census2021-ts023-oa
# Copied 80000 rows to census2021-ts023-oa
# Copied 85000 rows to census2021-ts023-oa
# Copied 90000 rows to census2021-ts023-oa
# Copied 95000 rows to census2021-ts023-oa
# Copied 100000 rows to census2021-ts023-oa
# Copied 105000 rows to census2021-ts023-oa
# Copied 110000 rows to census2021-ts023-oa
# Copied 115000 rows to census2021-ts023-oa
# Copied 120000 rows to census2021-ts023-oa
# Copied 125000 rows to census2021-ts023-oa
# Copied 130000 rows to census2021-ts023-oa
# Copied 135000 rows to census2021-ts023-oa
# Copied 140000 rows to census2021-ts023-oa
# Copied 145000 rows to census2021-ts023-oa
# Copied 150000 rows to census2021-ts023-oa
# Copied 155000 rows to census2021-ts023-oa
# Copied 160000 rows to census2021-ts023-oa
# Copied 165000 rows to census2021-ts023-oa
# Copied 170000 rows to census2021-ts023-oa
# Copied 175000 rows to census2021-ts023-oa
# Copied 180000 rows to census2021-ts023-oa
# Copied 185000 rows to census2021-ts023-oa
# Copied 188880 rows to census2021-ts023-oa
# Copying table: census2021-ts023-ctry
# Copied 3 rows to census2021-ts023-ctry
# Copying table: census2021-ts023-ltla
# Copied 331 rows to census2021-ts023-ltla
# Copying table: census2021-ts023-msoa
# Copied 5000 rows to census2021-ts023-msoa
# Copied 7264 rows to census2021-ts023-msoa
# Copying table: users
# Copied 1 rows to users
# All tables copied successfully from local to remote database.

# %%
import os
import psycopg2
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

# Local database connection parameters
LOCAL_DB_HOST = os.getenv('DB_HOST')
LOCAL_DB_PORT = os.getenv('DB_PORT')
LOCAL_DB_USER = os.getenv('DB_USER')
LOCAL_DB_NAME = os.getenv('DB_NAME')
LOCAL_DB_PASSWORD = os.getenv('DB_PASSWORD')  # Add this to your .env if needed

# Connect to the local database
local_conn = psycopg2.connect(
    host=LOCAL_DB_HOST,
    port=LOCAL_DB_PORT,
    user=LOCAL_DB_USER,
    dbname=LOCAL_DB_NAME,
    password=LOCAL_DB_PASSWORD
)
local_cur = local_conn.cursor()

# Function to get the row count of a table
def get_row_count(table_name):
    local_cur.execute(f"SELECT COUNT(*) FROM {table_name};")
    row_count = local_cur.fetchone()[0]
    return row_count

# Function to get 10 random rows from a table
def get_random_rows(table_name):
    local_cur.execute(f"SELECT * FROM {table_name} ORDER BY RANDOM() LIMIT 10;")
    random_rows = local_cur.fetchall()
    return random_rows

# Get the row count for the 'geography_mappings' table
table_name = 'geography_mappings'
row_count = get_row_count(table_name)
print(f"Number of rows in {table_name}: {row_count}")

# Get 10 random rows from the 'geography_mappings' table
random_rows = get_random_rows(table_name)
print(f"10 random rows from {table_name}: {random_rows}")

# Close the cursor and connection
local_cur.close()
local_conn.close()
# Out:
# Number of rows in geography_mappings: 2352552
# 10 random rows from geography_mappings: [('England', 'Yorkshire and The Humber', 'East Riding of Yorkshire', 'East Riding of Yorkshire', 'East Riding of Yorkshire 020', 'East Riding of Yorkshire 020B', 'E00065207', None), ('England', 'London', 'Westminster', 'Westminster', 'Westminster 007', 'Westminster 007B', 'E00023746', None), ('England', 'South West', 'Dorset', 'Dorset', 'Dorset 038', 'Dorset 038A', 'E00104241', None), ('England', 'London', 'Westminster', 'Westminster', 'Westminster 020', 'Westminster 020C', 'E00023945', None), ('England', 'London', 'Hillingdon', 'Hillingdon', 'Hillingdon 019', 'Hillingdon 019B', 'E00012011', None), ('England', 'North West', 'Cheshire East', 'Cheshire East', 'Cheshire East 007', 'Cheshire East 007C', 'E00094118', None), ('England', 'London', 'Hammersmith and Fulham', 'Hammersmith and Fulham', 'Hammersmith and Fulham 012', 'Hammersmith and Fulham 012A', 'E00009345', None), ('England', 'South East', 'West Berkshire', 'West Berkshire', 'West Berkshire 015', 'West Berkshire 015A', 'E00082191', None), ('England', 'South East', 'Reading', 'Reading', 'Reading 010', 'Reading 010G', 'E00082616', None), ('England', 'North West', 'Warrington', 'Warrington', 'Warrington 008', 'Warrington 008C', 'E00063244', None)]

# %%
import json

# Provided JSON data
json_example = {
    "TS021": {
        "name": "Ethnic group",
        "table_names": [
            "census2021-ts021-msoa",
            "census2021-ts021-ltla",
            "census2021-ts021-ctry",
            "census2021-ts021-oa",
            "census2021-ts021-rgn",
            "census2021-ts021-utla",
            "census2021-ts021-lsoa"
        ]
    },
    "TS022": {
        "name": "Ethnic group (detailed)",
        "table_names": [
            "census2021-ts022-rgn",
            "census2021-ts022-utla",
            "census2021-ts022-ctry",
            "census2021-ts022-ltla",
            "census2021-ts022-msoa"
        ]
    },
    "TS030": {
        "name": "Religion",
        "table_names": [
            "census2021-ts030-msoa",
            "census2021-ts030-rgn",
            "census2021-ts030-ltla",
            "census2021-ts030-ctry",
            "census2021-ts030-utla",
            "census2021-ts030-lsoa",
            "census2021-ts030-oa"
        ]
    },
    "TS031": {
        "name": "Religion (detailed)",
        "table_names": [
            "census2021-ts031-msoa",
            "census2021-ts031-ltla",
            "census2021-ts031-ctry",
            "census2021-ts031-rgn",
            "census2021-ts031-utla"
        ]
    }
}

json_to_update = {
    "TS001": {
        "name": "Number of usual residents in households and communal establishments",
        "table_names": []
    },
    "TS002": {
        "name": "Legal partnership status",
        "table_names": []
    },
    "TS003": {
        "name": "Household composition",
        "table_names": []
    },
    "TS004": {
        "name": "Country of birth",
        "table_names": []
    },
    "TS005": {
        "name": "Passports held",
        "table_names": []
    },
    "TS006": {
        "name": "Population density",
        "table_names": []
    },
    "TS007": {
        "name": "Age by single year of age",
        "table_names": []
    },
    "TS007A": {
        "name": "Age by five-year age bands",
        "table_names": []
    },
    "TS008": {
        "name": "Sex",
        "table_names": []
    },
    "TS009": {
        "name": "Sex by single year of age",
        "table_names": []
    },
    "TS010": {
        "name": "Living arrangements",
        "table_names": []
    },
    "TS011": {
        "name": "Households by deprivation dimensions",
        "table_names": []
    },
    "TS012": {
        "name": "Country of birth (detailed)",
        "table_names": []
    },
    "TS013": {
        "name": "Passports held (detailed)",
        "table_names": []
    },
    "TS015": {
        "name": "Year of arrival in UK",
        "table_names": []
    },
    "TS016": {
        "name": "Length of residence",
        "table_names": []
    },
    "TS017": {
        "name": "Household size",
        "table_names": []
    },
    "TS018": {
        "name": "Age of arrival in the UK",
        "table_names": []
    },
    "TS019": {
        "name": "Migrant Indicator",
        "table_names": []
    },
    "TS020": {
        "name": "Number of non-UK short-term residents by sex",
        "table_names": []
    },
    "TS041": {
        "name": "Number of Households",
        "table_names": []
    },
    "TS021": {
        "name": "Ethnic group",
        "table_names": [
            "census2021-ts021-msoa",
            "census2021-ts021-ltla",
            "census2021-ts021-ctry",
            "census2021-ts021-oa",
            "census2021-ts021-rgn",
            "census2021-ts021-utla",
            "census2021-ts021-lsoa"
        ]
    },
    "TS022": {
        "name": "Ethnic group (detailed)",
        "table_names": [
            "census2021-ts022-rgn",
            "census2021-ts022-utla",
            "census2021-ts022-ctry",
            "census2021-ts022-ltla",
            "census2021-ts022-msoa"
        ]
    },
    "TS023": {
        "name": "Multiple ethnic group",
        "table_names": []
    },
    "TS024": {
        "name": "Main language (detailed)",
        "table_names": []
    },
    "TS025": {
        "name": "Household language",
        "table_names": []
    },
    "TS026": {
        "name": "Multiple main languages in households",
        "table_names": []
    },
    "TS027": {
        "name": "National identity - UK",
        "table_names": []
    },
    "TS028": {
        "name": "National identity (detailed)",
        "table_names": []
    },
    "TS029": {
        "name": "Proficiency in english",
        "table_names": []
    },
    "TS030": {
        "name": "Religion",
        "table_names": []
    },
    "TS031": {
        "name": "Religion (detailed)",
        "table_names": []
    },
    "TS075": {
        "name": "Multi religion households",
        "table_names": []
    }
}

# Function to generate table_names
def generate_table_names(key):
    areas = ["msoa", "ltla", "ctry", "oa", "rgn", "utla", "lsoa"]
    return [f"census2021-{key.lower()}-{area}" for area in areas]

# Update json_to_update with table_names
for key in json_to_update:
    if not json_to_update[key]["table_names"]:
        json_to_update[key]["table_names"] = generate_table_names(key)

# Print updated json_to_update
print(json.dumps(json_to_update, indent=2))
# Out:
# {
#   "TS001": {
#     "name": "Number of usual residents in households and communal establishments",
#     "table_names": [
#       "census2021-ts001-msoa",
#       "census2021-ts001-ltla",
#       "census2021-ts001-ctry",
#       "census2021-ts001-oa",
#       "census2021-ts001-rgn",
#       "census2021-ts001-utla",
#       "census2021-ts001-lsoa"
#     ]
#   },
#   "TS002": {
#     "name": "Legal partnership status",
#     "table_names": [
#       "census2021-ts002-msoa",
#       "census2021-ts002-ltla",
#       "census2021-ts002-ctry",
#       "census2021-ts002-oa",
#       "census2021-ts002-rgn",
#       "census2021-ts002-utla",
#       "census2021-ts002-lsoa"
#     ]
#   },
#   "TS003": {
#     "name": "Household composition",
#     "table_names": [
#       "census2021-ts003-msoa",
#       "census2021-ts003-ltla",
#       "census2021-ts003-ctry",
#       "census2021-ts003-oa",
#       "census2021-ts003-rgn",
#       "census2021-ts003-utla",
#       "census2021-ts003-lsoa"
#     ]
#   },
#   "TS004": {
#     "name": "Country of birth",
#     "table_names": [
#       "census2021-ts004-msoa",
#       "census2021-ts004-ltla",
#       "census2021-ts004-ctry",
#       "census2021-ts004-oa",
#       "census2021-ts004-rgn",
#       "census2021-ts004-utla",
#       "census2021-ts004-lsoa"
#     ]
#   },
#   "TS005": {
#     "name": "Passports held",
#     "table_names": [
#       "census2021-ts005-msoa",
#       "census2021-ts005-ltla",
#       "census2021-ts005-ctry",
#       "census2021-ts005-oa",
#       "census2021-ts005-rgn",
#       "census2021-ts005-utla",
#       "census2021-ts005-lsoa"
#     ]
#   },
#   "TS006": {
#     "name": "Population density",
#     "table_names": [
#       "census2021-ts006-msoa",
#       "census2021-ts006-ltla",
#       "census2021-ts006-ctry",
#       "census2021-ts006-oa",
#       "census2021-ts006-rgn",
#       "census2021-ts006-utla",
#       "census2021-ts006-lsoa"
#     ]
#   },
#   "TS007": {
#     "name": "Age by single year of age",
#     "table_names": [
#       "census2021-ts007-msoa",
#       "census2021-ts007-ltla",
#       "census2021-ts007-ctry",
#       "census2021-ts007-oa",
#       "census2021-ts007-rgn",
#       "census2021-ts007-utla",
#       "census2021-ts007-lsoa"
#     ]
#   },
#   "TS007A": {
#     "name": "Age by five-year age bands",
#     "table_names": [
#       "census2021-ts007a-msoa",
#       "census2021-ts007a-ltla",
#       "census2021-ts007a-ctry",
#       "census2021-ts007a-oa",
#       "census2021-ts007a-rgn",
#       "census2021-ts007a-utla",
#       "census2021-ts007a-lsoa"
#     ]
#   },
#   "TS008": {
#     "name": "Sex",
#     "table_names": [
#       "census2021-ts008-msoa",
#       "census2021-ts008-ltla",
#       "census2021-ts008-ctry",
#       "census2021-ts008-oa",
#       "census2021-ts008-rgn",
#       "census2021-ts008-utla",
#       "census2021-ts008-lsoa"
#     ]
#   },
#   "TS009": {
#     "name": "Sex by single year of age",
#     "table_names": [
#       "census2021-ts009-msoa",
#       "census2021-ts009-ltla",
#       "census2021-ts009-ctry",
#       "census2021-ts009-oa",
#       "census2021-ts009-rgn",
#       "census2021-ts009-utla",
#       "census2021-ts009-lsoa"
#     ]
#   },
#   "TS010": {
#     "name": "Living arrangements",
#     "table_names": [
#       "census2021-ts010-msoa",
#       "census2021-ts010-ltla",
#       "census2021-ts010-ctry",
#       "census2021-ts010-oa",
#       "census2021-ts010-rgn",
#       "census2021-ts010-utla",
#       "census2021-ts010-lsoa"
#     ]
#   },
#   "TS011": {
#     "name": "Households by deprivation dimensions",
#     "table_names": [
#       "census2021-ts011-msoa",
#       "census2021-ts011-ltla",
#       "census2021-ts011-ctry",
#       "census2021-ts011-oa",
#       "census2021-ts011-rgn",
#       "census2021-ts011-utla",
#       "census2021-ts011-lsoa"
#     ]
#   },
#   "TS012": {
#     "name": "Country of birth (detailed)",
#     "table_names": [
#       "census2021-ts012-msoa",
#       "census2021-ts012-ltla",
#       "census2021-ts012-ctry",
#       "census2021-ts012-oa",
#       "census2021-ts012-rgn",
#       "census2021-ts012-utla",
#       "census2021-ts012-lsoa"
#     ]
#   },
#   "TS013": {
#     "name": "Passports held (detailed)",
#     "table_names": [
#       "census2021-ts013-msoa",
#       "census2021-ts013-ltla",
#       "census2021-ts013-ctry",
#       "census2021-ts013-oa",
#       "census2021-ts013-rgn",
#       "census2021-ts013-utla",
#       "census2021-ts013-lsoa"
#     ]
#   },
#   "TS015": {
#     "name": "Year of arrival in UK",
#     "table_names": [
#       "census2021-ts015-msoa",
#       "census2021-ts015-ltla",
#       "census2021-ts015-ctry",
#       "census2021-ts015-oa",
#       "census2021-ts015-rgn",
#       "census2021-ts015-utla",
#       "census2021-ts015-lsoa"
#     ]
#   },
#   "TS016": {
#     "name": "Length of residence",
#     "table_names": [
#       "census2021-ts016-msoa",
#       "census2021-ts016-ltla",
#       "census2021-ts016-ctry",
#       "census2021-ts016-oa",
#       "census2021-ts016-rgn",
#       "census2021-ts016-utla",
#       "census2021-ts016-lsoa"
#     ]
#   },
#   "TS017": {
#     "name": "Household size",
#     "table_names": [
#       "census2021-ts017-msoa",
#       "census2021-ts017-ltla",
#       "census2021-ts017-ctry",
#       "census2021-ts017-oa",
#       "census2021-ts017-rgn",
#       "census2021-ts017-utla",
#       "census2021-ts017-lsoa"
#     ]
#   },
#   "TS018": {
#     "name": "Age of arrival in the UK",
#     "table_names": [
#       "census2021-ts018-msoa",
#       "census2021-ts018-ltla",
#       "census2021-ts018-ctry",
#       "census2021-ts018-oa",
#       "census2021-ts018-rgn",
#       "census2021-ts018-utla",
#       "census2021-ts018-lsoa"
#     ]
#   },
#   "TS019": {
#     "name": "Migrant Indicator",
#     "table_names": [
#       "census2021-ts019-msoa",
#       "census2021-ts019-ltla",
#       "census2021-ts019-ctry",
#       "census2021-ts019-oa",
#       "census2021-ts019-rgn",
#       "census2021-ts019-utla",
#       "census2021-ts019-lsoa"
#     ]
#   },
#   "TS020": {
#     "name": "Number of non-UK short-term residents by sex",
#     "table_names": [
#       "census2021-ts020-msoa",
#       "census2021-ts020-ltla",
#       "census2021-ts020-ctry",
#       "census2021-ts020-oa",
#       "census2021-ts020-rgn",
#       "census2021-ts020-utla",
#       "census2021-ts020-lsoa"
#     ]
#   },
#   "TS041": {
#     "name": "Number of Households",
#     "table_names": [
#       "census2021-ts041-msoa",
#       "census2021-ts041-ltla",
#       "census2021-ts041-ctry",
#       "census2021-ts041-oa",
#       "census2021-ts041-rgn",
#       "census2021-ts041-utla",
#       "census2021-ts041-lsoa"
#     ]
#   },
#   "TS021": {
#     "name": "Ethnic group",
#     "table_names": [
#       "census2021-ts021-msoa",
#       "census2021-ts021-ltla",
#       "census2021-ts021-ctry",
#       "census2021-ts021-oa",
#       "census2021-ts021-rgn",
#       "census2021-ts021-utla",
#       "census2021-ts021-lsoa"
#     ]
#   },
#   "TS022": {
#     "name": "Ethnic group (detailed)",
#     "table_names": [
#       "census2021-ts022-rgn",
#       "census2021-ts022-utla",
#       "census2021-ts022-ctry",
#       "census2021-ts022-ltla",
#       "census2021-ts022-msoa"
#     ]
#   },
#   "TS023": {
#     "name": "Multiple ethnic group",
#     "table_names": [
#       "census2021-ts023-msoa",
#       "census2021-ts023-ltla",
#       "census2021-ts023-ctry",
#       "census2021-ts023-oa",
#       "census2021-ts023-rgn",
#       "census2021-ts023-utla",
#       "census2021-ts023-lsoa"
#     ]
#   },
#   "TS024": {
#     "name": "Main language (detailed)",
#     "table_names": [
#       "census2021-ts024-msoa",
#       "census2021-ts024-ltla",
#       "census2021-ts024-ctry",
#       "census2021-ts024-oa",
#       "census2021-ts024-rgn",
#       "census2021-ts024-utla",
#       "census2021-ts024-lsoa"
#     ]
#   },
#   "TS025": {
#     "name": "Household language",
#     "table_names": [
#       "census2021-ts025-msoa",
#       "census2021-ts025-ltla",
#       "census2021-ts025-ctry",
#       "census2021-ts025-oa",
#       "census2021-ts025-rgn",
#       "census2021-ts025-utla",
#       "census2021-ts025-lsoa"
#     ]
#   },
#   "TS026": {
#     "name": "Multiple main languages in households",
#     "table_names": [
#       "census2021-ts026-msoa",
#       "census2021-ts026-ltla",
#       "census2021-ts026-ctry",
#       "census2021-ts026-oa",
#       "census2021-ts026-rgn",
#       "census2021-ts026-utla",
#       "census2021-ts026-lsoa"
#     ]
#   },
#   "TS027": {
#     "name": "National identity - UK",
#     "table_names": [
#       "census2021-ts027-msoa",
#       "census2021-ts027-ltla",
#       "census2021-ts027-ctry",
#       "census2021-ts027-oa",
#       "census2021-ts027-rgn",
#       "census2021-ts027-utla",
#       "census2021-ts027-lsoa"
#     ]
#   },
#   "TS028": {
#     "name": "National identity (detailed)",
#     "table_names": [
#       "census2021-ts028-msoa",
#       "census2021-ts028-ltla",
#       "census2021-ts028-ctry",
#       "census2021-ts028-oa",
#       "census2021-ts028-rgn",
#       "census2021-ts028-utla",
#       "census2021-ts028-lsoa"
#     ]
#   },
#   "TS029": {
#     "name": "Proficiency in english",
#     "table_names": [
#       "census2021-ts029-msoa",
#       "census2021-ts029-ltla",
#       "census2021-ts029-ctry",
#       "census2021-ts029-oa",
#       "census2021-ts029-rgn",
#       "census2021-ts029-utla",
#       "census2021-ts029-lsoa"
#     ]
#   },
#   "TS030": {
#     "name": "Religion",
#     "table_names": [
#       "census2021-ts030-msoa",
#       "census2021-ts030-ltla",
#       "census2021-ts030-ctry",
#       "census2021-ts030-oa",
#       "census2021-ts030-rgn",
#       "census2021-ts030-utla",
#       "census2021-ts030-lsoa"
#     ]
#   },
#   "TS031": {
#     "name": "Religion (detailed)",
#     "table_names": [
#       "census2021-ts031-msoa",
#       "census2021-ts031-ltla",
#       "census2021-ts031-ctry",
#       "census2021-ts031-oa",
#       "census2021-ts031-rgn",
#       "census2021-ts031-utla",
#       "census2021-ts031-lsoa"
#     ]
#   },
#   "TS075": {
#     "name": "Multi religion households",
#     "table_names": [
#       "census2021-ts075-msoa",
#       "census2021-ts075-ltla",
#       "census2021-ts075-ctry",
#       "census2021-ts075-oa",
#       "census2021-ts075-rgn",
#       "census2021-ts075-utla",
#       "census2021-ts075-lsoa"
#     ]
#   }
# }

# %%
import csv

with open('data/Scotland/OA_TO_HIGHER_AREAS.csv', 'r') as file:
    reader = csv.reader(file)
    
    # Read header row to get column names
    headers = next(reader)
    
    # Initialize dictionary to store unique values for each column
    unique_values = {col: set() for col in headers}
    
    # Iterate over each row
    for row in reader:
        # Iterate over each column in the row
        for col, value in zip(headers, row):
            unique_values[col].add(value)

# Print number of unique values for each column            
for col, values in unique_values.items():
    print(f"{col}: {len(values)} unique values")
# Out:
# OA2022: 46363 unique values
# CA2019: 32 unique values
# EW2022: 355 unique values
# DZ2011: 6972 unique values
# CP1930: 859 unique values
# SPC2021: 73 unique values
# HBA2019: 14 unique values
# CSETT2022: 504 unique values
# CLOC2022: 657 unique values
# UKPC2005: 59 unique values
# ISLG2022: 53 unique values
# SPR2021: 8 unique values
# IA2019: 31 unique values
# NP2010: 3 unique values
# IZ2011: 1279 unique values
# ITL2_21: 5 unique values
# ITL3_21: 23 unique values
# SIMD2020: 6972 unique values
# MasterPC: 46363 unique values
# Easting: 39233 unique values
# Northing: 36255 unique values
# Hect: 6422 unique values
# SqKM: 46363 unique values

# %%
import csv
import json

# Read the CSV file and extract unique geography values
unique_geographies = set()
with open('data/SC/census2022-uv205/census2022-uv205-ca.csv', 'r') as file:
    csv_reader = csv.DictReader(file)
    for row in csv_reader:
        unique_geographies.add(row['geography'])

# Create a dictionary with the formatted output
output = {
    "Scotland": sorted(unique_geographies)
}

# Convert the dictionary to JSON format
json_output = json.dumps(output, indent=4)

# Print the formatted output
print(json_output)
# Out:
# {
#     "Scotland": [
#         "Aberdeen City",
#         "Aberdeenshire",
#         "Angus",
#         "Argyll and Bute",
#         "City of Edinburgh",
#         "Clackmannanshire",
#         "Dumfries and Galloway",
#         "Dundee City",
#         "East Ayrshire",
#         "East Dunbartonshire",
#         "East Lothian",
#         "East Renfrewshire",
#         "Falkirk",
#         "Fife",
#         "Glasgow City",
#         "Highland",
#         "Inverclyde",
#         "Midlothian",
#         "Moray",
#         "Na h-Eileanan Siar",
#         "North Ayrshire",
#         "North Lanarkshire",
#         "Orkney Islands",
#         "Perth and Kinross",
#         "Renfrewshire",
#         "Scottish Borders",
#         "Shetland Islands",
#         "South Ayrshire",
#         "South Lanarkshire",
#         "Stirling",
#         "West Dunbartonshire",
#         "West Lothian"
#     ]
# }

# %%
import pandas as pd

# Load the temp.csv file
temp_df = pd.read_csv('data/SC/census2022-uv205/temp.csv')

# Load the census2022-uv205-ca.csv file
census_df = pd.read_csv('data/SC/census2022-uv205/census2022-uv205-ca.csv')

# Check if the "geography code" column exists in temp_df
if 'geography code' in temp_df.columns:
    # Add the "geography code" column to census_df
    census_df["geography code"] = temp_df["geography code"]
else:
    print("The column 'geography code' does not exist in temp.csv")

# Save the updated census_df to a new CSV file
census_df.to_csv('data/SC/census2022-uv205/updated_census2022-uv205-ca.csv', index=False)

print("The 'geography code' column has been copied successfully.")
# Out:
# The 'geography code' column has been added to the census2022-uv205-ca table in the remote database successfully.

# %%
import pandas as pd
from sqlalchemy import create_engine

# Database connection parameters
REMOTE_DATABASE_URL = "postgresql://udvgghkgvhno05:pdb4ac0e3d9341327385cc1514256906b3ea3cee34a8bfca9f9878e3ecb829408@c6i386kdr73gcp.cluster-czz5s0kz4scl.eu-west-1.rds.amazonaws.com:5432/d3p1stj7ab710b"

# Load the temp.csv file
temp_df = pd.read_csv('data/SC/census2022-uv205/temp.csv')

# Ensure the "geography code" column exists
if 'geography code' not in temp_df.columns:
    raise ValueError("The column 'geography code' does not exist in temp.csv")

# Connect to the remote PostgreSQL database
engine = create_engine(REMOTE_DATABASE_URL)
connection = engine.connect()

# Load the census2022-uv205-ca table from the database
census_df = pd.read_sql_table('census2022-uv205-ca', connection)

# Ensure the dataframes have the same number of rows
if len(temp_df) != len(census_df):
    raise ValueError("The number of rows in temp.csv does not match the number of rows in census2022-uv205-ca")

# Add the "geography code" column to the census dataframe
census_df['geography code'] = temp_df['geography code']

# Update the census2022-uv205-ca table in the database
census_df.to_sql('census2022-uv205-ca', connection, if_exists='replace', index=False)

# Close the connection
connection.close()

print("The 'geography code' column has been added to the census2022-uv205-ca table in the remote database successfully.")

# %%
import pandas as pd
from sqlalchemy import create_engine

# Database connection parameters
REMOTE_DATABASE_URL = "postgresql://udvgghkgvhno05:pdb4ac0e3d9341327385cc1514256906b3ea3cee34a8bfca9f9878e3ecb829408@c6i386kdr73gcp.cluster-czz5s0kz4scl.eu-west-1.rds.amazonaws.com:5432/d3p1stj7ab710b"

# Load the OA_TO_HIGHER_AREAS.csv file
oa_to_higher_areas_df = pd.read_csv('data/SC/OA_TO_HIGHER_AREAS.csv')

# Ensure the columns "OA2022" and "CA2019" exist
if 'OA2022' not in oa_to_higher_areas_df.columns or 'CA2019' not in oa_to_higher_areas_df.columns:
    raise ValueError("The required columns 'OA2022' and 'CA2019' do not exist in OA_TO_HIGHER_AREAS.csv")

# Rename the columns to match the desired names
oa_to_higher_areas_df = oa_to_higher_areas_df.rename(columns={'OA2022': 'oa', 'CA2019': 'ca'})
print(oa_to_higher_areas_df.head())

# Connect to the remote PostgreSQL database
engine = create_engine(REMOTE_DATABASE_URL)
connection = engine.connect()

# Load the geography_mappings table from the database
geography_mappings_df = pd.read_sql_table('geography_mappings', connection)

# Append the new rows from oa_to_higher_areas_df to geography_mappings_df
appended_df = pd.concat([geography_mappings_df, oa_to_higher_areas_df[['oa', 'ca']]], ignore_index=True)

# Update the geography_mappings table in the database with the new rows appended
appended_df.to_sql('geography_mappings', connection, if_exists='replace', index=False)

# Close the connection
connection.close()

print("The new rows from 'oa' and 'ca' have been added to the geography_mappings table in the remote database successfully.")
# Out:
#           oa         ca     EW2022     DZ2011     CP1930    SPC2021  \
# 0  S00135307  S12000033  S13002835  S01006755  S35000272  S16000075
# 1  S00135308  S12000033  S13002835  S01006755  S35000272  S16000075
# 2  S00135309  S12000033  S13002836  S01006788  S35000669  S16000075
# 3  S00135310  S12000033  S13002835  S01006755  S35000272  S16000075
# 4  S00135311  S12000033  S13002835  S01006762  S35000669  S16000075
#
#      HBA2019  CSETT2022   CLOC2022   UKPC2005  ... NP2010     IZ2011 ITL2_21  \
# 0  S08000020        NaN        NaN  S14000037  ...    NaN  S02001278    TLM5
# 1  S08000020        NaN        NaN  S14000037  ...    NaN  S02001278    TLM5
# 2  S08000020        NaN        NaN  S14000037  ...    NaN  S02001284    TLM5
# 3  S08000020  S53000002  S52000220  S14000037  ...    NaN  S02001278    TLM5
# 4  S08000020        NaN        NaN  S14000037  ...    NaN  S02001280    TLM5
#
#   ITL3_21 SIMD2020   MasterPC Easting  Northing     Hect       SqKM
# 0   TLM50     4563   AB21 0EQ  387134    814107  1094.57  10.945682
# 1   TLM50     4563  AB21 0TBA  383492    813678   541.00   5.410016
# 2   TLM50     4856   AB23 8NT  394424    813027  1015.63  10.156310
# 3   TLM50     4563   AB21 7ER  388631    813387    77.35   0.773541
# 4   TLM50     5401   AB22 8AR  389960    811852   780.52   7.805181
#
# [5 rows x 23 columns]
# The new rows from 'oa' and 'ca' have been added to the geography_mappings table in the remote database successfully.

# %%
import pandas as pd
from sqlalchemy import create_engine

# Database connection parameters
REMOTE_DATABASE_URL = "postgresql://udvgghkgvhno05:pdb4ac0e3d9341327385cc1514256906b3ea3cee34a8bfca9f9878e3ecb829408@c6i386kdr73gcp.cluster-czz5s0kz4scl.eu-west-1.rds.amazonaws.com:5432/d3p1stj7ab710b"

# Connect to the remote PostgreSQL database
engine = create_engine(REMOTE_DATABASE_URL)
connection = engine.connect()

# Load the census2022-uv205-ca table from the database
census_df = pd.read_sql_table('census2022-uv205-ca', connection)

# Load the geography_mappings table from the database
geography_mappings_df = pd.read_sql_table('geography_mappings', connection)

# Merge the geography_mappings table with the census2022-uv205-ca table on "ca" and "geography code"
merged_df = geography_mappings_df.merge(census_df[['geography code', 'geography']], how='left', left_on='ca', right_on='geography code')

# Rename the "geography" column to "ca_nm"
merged_df.rename(columns={'geography': 'ca_nm'}, inplace=True)

# Drop the unnecessary "geography code" column
merged_df.drop(columns=['geography code'], inplace=True)

# Update the geography_mappings table in the database
merged_df.to_sql('geography_mappings', connection, if_exists='replace', index=False)

# Close the connection
connection.close()

print("The 'ca_nm' column has been added to the geography_mappings table in the remote database successfully.")
# Out:
# The 'ca_nm' column has been added to the geography_mappings table in the remote database successfully.

# %%
import pandas as pd
from sqlalchemy import create_engine

# Database connection parameters
REMOTE_DATABASE_URL = "postgresql://udvgghkgvhno05:pdb4ac0e3d9341327385cc1514256906b3ea3cee34a8bfca9f9878e3ecb829408@c6i386kdr73gcp.cluster-czz5s0kz4scl.eu-west-1.rds.amazonaws.com:5432/d3p1stj7ab710b"

# Load the local files
data_zone_df = pd.read_csv('data/SC/DataZone2011lookup.csv', encoding='ISO-8859-1')
oa_to_higher_areas_df = pd.read_csv('data/SC/OA_TO_HIGHER_AREAS.csv')

# Merge the local files to create a mapping
mapping_df = oa_to_higher_areas_df.merge(data_zone_df, how='left', left_on='DZ2011', right_on='DZ2011_Code')

# Connect to the remote PostgreSQL database
engine = create_engine(REMOTE_DATABASE_URL)
connection = engine.connect()

# Load the geography_mappings table from the database
geography_mappings_df = pd.read_sql_table('geography_mappings', connection)

# Merge the geography_mappings table with the mapping dataframe on 'oa'
geography_mappings_df = geography_mappings_df.merge(mapping_df[['OA2022', 'DZ2011_Code', 'DZ2011_Name']], how='left', left_on='oa', right_on='OA2022')

# Rename the columns
geography_mappings_df.rename(columns={'DZ2011_Code': 'dz', 'DZ2011_Name': 'dz_nm'}, inplace=True)

# Drop the unnecessary 'OA2022' column
geography_mappings_df.drop(columns=['OA2022'], inplace=True)

# Update the geography_mappings table in the database
geography_mappings_df.to_sql('geography_mappings', connection, if_exists='replace', index=False)

# Close the connection
connection.close()

print("The 'dz' and 'dz_nm' columns have been added to the geography_mappings table in the remote database successfully.")
# Out:
# The 'dz' and 'dz_nm' columns have been added to the geography_mappings table in the remote database successfully.

# %%
import pandas as pd
from sqlalchemy import create_engine, text

# Database connection parameters
REMOTE_DATABASE_URL = "postgresql://udvgghkgvhno05:pdb4ac0e3d9341327385cc1514256906b3ea3cee34a8bfca9f9878e3ecb829408@c6i386kdr73gcp.cluster-czz5s0kz4scl.eu-west-1.rds.amazonaws.com:5432/d3p1stj7ab710b"

# Load the local files with specified encoding
data_zone_df = pd.read_csv('data/SC/DataZone2011lookup.csv', encoding='ISO-8859-1')
oa_to_higher_areas_df = pd.read_csv('data/SC/OA_TO_HIGHER_AREAS.csv')

# Merge the local files to create a mapping
mapping_df = oa_to_higher_areas_df.merge(data_zone_df, how='left', left_on='IZ2011', right_on='IZ2011_Code')

# Select only the necessary columns
mapping_df = mapping_df[['OA2022', 'IZ2011_Code', 'IZ2011_Name']]

# Connect to the remote PostgreSQL database
engine = create_engine(REMOTE_DATABASE_URL)
connection = engine.connect()

# Load the geography_mappings table from the database
geography_mappings_df = pd.read_sql_table('geography_mappings', connection)

# Merge the geography_mappings table with the mapping dataframe on 'oa'
geography_mappings_df = geography_mappings_df.merge(mapping_df[['OA2022', 'IZ2011_Code', 'IZ2011_Name']], how='left', left_on='oa', right_on='OA2022')

# Rename the columns
geography_mappings_df.rename(columns={'IZ2011_Code': 'iz', 'IZ2011_Name': 'iz_nm'}, inplace=True)

# Drop the unnecessary 'OA2022' column
geography_mappings_df.drop(columns=['OA2022'], inplace=True)

# Update the geography_mappings table in the database
geography_mappings_df.to_sql('geography_mappings', connection, if_exists='replace', index=False)

# Close the connection
connection.close()

print("The 'iz' and 'iz_nm' columns have been added to the geography_mappings table in the remote database successfully.")
# Out:
# The 'iz' and 'iz_nm' columns have been added to the geography_mappings table in the remote database successfully.
